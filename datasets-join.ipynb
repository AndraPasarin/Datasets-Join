# %% [markdown]
# <a href="https://www.kaggle.com/code/andrapsrin/datasets-join?scriptVersionId=170946062" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Step 1: Data Reading
#
# In order to read the data, we need to handle entries that have commas inside the content of one of the columns. This causes the csv format to throw an error while parsing the data because it can’t distinguish between commas in text versus commas for delimiting columns. An easy fix would be to check if the comma is found between " " (this is the case for the text columns), but not all values fit this requirement so it becomes difficult to differentiate the commas.
#
# To have a clear understanding of the innacurate data, the number of skipped lines will be printed.

# %%
import pandas as pd
import numpy as np

# count the number of lines skipped in google dataset

file_path = '/kaggle/input/companies/google_dataset.csv'

# count total lines in the file
with open(file_path) as f:
    total_lines = sum(1 for line in f)

# read the CSV, skipping bad lines
gd = pd.read_csv(file_path, low_memory=False, on_bad_lines='skip')

# copy for later ;) ... to check duplicates..
gd_copy = gd.copy()

# calculate number of lines skipped
lines_skipped = total_lines - len(gd) - 1  # subtract 1 for the header
percentage_skipped_lines = (lines_skipped/total_lines)*100

print(f"Number of lines skipped in google dataset: {lines_skipped}")
print(f"Number of total entries in google dataset: {total_lines}")
print(f"Percentage of skipped lines: {percentage_skipped_lines:.2f} %")
# Out:
# Number of lines skipped in google dataset: 9595
# Number of total entries in google dataset: 356521
# Percentage of skipped lines: 2.69 %

# %%
# count the number of lines skipped in facebook dataset

file_path = '/kaggle/input/companies/facebook_dataset.csv'

# count total lines in the file
with open(file_path) as f:
    total_lines = sum(1 for line in f)

# read the CSV, skipping bad lines
fd = pd.read_csv(file_path, low_memory=False, on_bad_lines='skip')

# calculate number of lines skipped
lines_skipped = total_lines - len(fd) - 1  # subtract 1 for the header
percentage_skipped_lines = (lines_skipped/total_lines)*100

print(f"Number of lines skipped in facebook dataset: {lines_skipped}")
print(f"Number of total entries in facebook dataset: {total_lines}")
print(f"Percentage of skipped lines: {percentage_skipped_lines:.2f} %")
# Out:
# Number of lines skipped in facebook dataset: 913
# Number of total entries in facebook dataset: 72081
# Percentage of skipped lines: 1.27 %

# %% [markdown]
# We can see that skipping the lines that had parsing errors results in eliminating only 2.69% in google dataset and 1.27% in facebook dataset of the total entries. Looks good for now but we should try to regain those lines later...
#
# Another thing to mention is that the website dataset uses ";" to delimitate columns, but besides that, it is a really clean dataset!

# %%
wd = pd.read_csv('/kaggle/input/companies/website_dataset.csv', sep=';')
wd.head()
# Out:
#            root_domain domain_suffix language  \
# 0     converterman.com           NaN      NaN
# 1  clothesencounter.ca            ca       en
# 2       investa.com.au        com.au       en
# 3    timminsgarage.com           com       en
# 4         destinate.ca            ca       en
#
#                                    legal_name main_city main_country  \
# 0                                         NaN       NaN          NaN
# 1                                         NaN  cardigan       canada
# 2  Investa Wholesale Funds Management Limited  brisbane    australia
# 3                         Timmins Garage Inc.   timmins       canada
# 4                        Destinate Group Ltd.       NaN       Canada
#
#             main_region        phone               site_name  tld  \
# 0                   NaN          NaN                     NaN  NaN
# 1  prince edward island  13066937766       Clothes Encounter   ca
# 2            queensland  61282269300  Investa Property Group   au
# 3               ontario  18775896640          Timmins Garage  com
# 4                   NaN          NaN         Destinate Group   ca
#
#                            s_category
# 0                                 NaN
# 1       Shoes & Other Footwear Stores
# 2              Real Estate Developers
# 3  Automobile Dealers & Manufacturers
# 4                 Business Consulting

# %% [markdown]
# # Step 2: Data Preprocessing
#
# In order to compare values between different datasets, I need to clean all important values and for that I will proceed with the following steps:
# - change data type to string
# - change column names (same names for all 3 datasets)
# - convert to lowercase
# - remove punctuation, accents and extra spaces
# - remove company suffix (inc, llc, co, srl etc.)
# - handle special characters
#
# First I will need to get a glimpse of the datasets in order to change the column names. In this way the data will be uniform and my confusion will be minimised :)

# %%
# check column names
gd.info()
fd.info()
wd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346925 entries, 0 to 346924
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   address             321315 non-null  object
#  1   category            295862 non-null  object
#  2   city                302199 non-null  object
#  3   country_code        295361 non-null  object
#  4   country_name        302235 non-null  object
#  5   name                346893 non-null  object
#  6   phone               314789 non-null  object
#  7   phone_country_code  234104 non-null  object
#  8   raw_address         302909 non-null  object
#  9   raw_phone           318977 non-null  object
#  10  region_code         302049 non-null  object
#  11  region_name         302054 non-null  object
#  12  text                343411 non-null  object
#  13  zip_code            265646 non-null  object
#  14  domain              346923 non-null  object
# dtypes: object(15)
# memory usage: 39.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71167 entries, 0 to 71166
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   domain              71167 non-null  object
#  1   address             56690 non-null  object
#  2   categories          54593 non-null  object
#  3   city                44567 non-null  object
#  4   country_code        57191 non-null  object
#  5   country_name        44865 non-null  object
#  6   description         27189 non-null  object
#  7   email               19753 non-null  object
#  8   link                71167 non-null  object
#  9   name                71167 non-null  object
#  10  page_type           71163 non-null  object
#  11  phone               44349 non-null  float64
#  12  phone_country_code  37551 non-null  object
#  13  region_code         44562 non-null  object
#  14  region_name         44562 non-null  object
#  15  zip_code            35623 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 8.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72018 entries, 0 to 72017
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   root_domain    72017 non-null  object
#  1   domain_suffix  71900 non-null  object
#  2   language       66826 non-null  object
#  3   legal_name     31989 non-null  object
#  4   main_city      60966 non-null  object
#  5   main_country   64869 non-null  object
#  6   main_region    60933 non-null  object
#  7   phone          65640 non-null  object
#  8   site_name      68714 non-null  object
#  9   tld            71757 non-null  object
#  10  s_category     70634 non-null  object
# dtypes: object(11)
# memory usage: 6.0+ MB

# %%
# rename columns (shared ones)
gd.rename(columns={"country_name": "country", "region_name": "region", "text": "details"}, inplace=True)
fd.rename(columns={"categories": "category", "country_name": "country", "region_name": "region"}, inplace=True)
wd.rename(columns={"root_domain": "domain", "main_city": "city", "main_country": "country", "main_region": "region", "site_name": "name", "s_category": "category"}, inplace=True)

# convert objects to strings
gd = gd.astype('string')
fd = fd.astype('string')
wd = wd.astype('string')

# convert to lowercase
gd = gd.map(lambda s: s.lower() if type(s) == str else s)
fd = fd.map(lambda s: s.lower() if type(s) == str else s)
wd = wd.map(lambda s: s.lower() if type(s) == str else s)

fd.head()
# Out:
#                     domain                                            address  \
# 0       euro-hygiene-34.fr  134 rue entrepreneurs, za du vigné, 30420, cal...
# 1  lakesidehomeservices.ca                                               <NA>
# 2        rossiterboats.com                                               <NA>
# 3     caa-architecture.com  601 cordova st w # 270, v6b 1g1, vancouver, bc...
# 4            apexsurety.ca  unit 3 - 4 donald street, r3l 2t7, winnipeg, m...
#
#                                             category       city country_code  \
# 0                                               <NA>  calvisson           fr
# 1  appliance repair & maintenance|home builders &...       <NA>           ca
# 2        boats & yachts dealers|boat tours & cruises       <NA>         <NA>
# 3  architects & architectural services|other engi...  vancouver           ca
# 4                                               <NA>   winnipeg           ca
#
#   country                                        description  \
# 0  france                                               <NA>
# 1    <NA>                                               <NA>
# 2    <NA>  at rossiter boats we build semi-custom power b...
# 3  canada                                               <NA>
# 4  canada                                               <NA>
#
#                         email                             link  \
# 0                        <NA>       https://euro-hygiene-34.fr
# 1                        <NA>  https://lakesidehomeservices.ca
# 2      info@rossiterboats.com         http://rossiterboats.com
# 3  office@caa-arcitecture.com      http://caa-architecture.com
# 4                        <NA>            https://apexsurety.ca
#
#                                     name      page_type          phone  \
# 0                           euro hygiène  localbusiness           <NA>
# 1                 lakeside home services  localbusiness  16138318840.0
# 2                         rossiter boats  localbusiness           <NA>
# 3  chandler associates architecture inc.  localbusiness  16046873390.0
# 4           apex surety & insurance ltd.  localbusiness  12045602508.0
#
#   phone_country_code region_code            region zip_code
# 0               <NA>         occ         occitanie    30420
# 1                 ca        <NA>              <NA>     <NA>
# 2               <NA>        <NA>              <NA>     <NA>
# 3                 ca          bc  british columbia  v6b 1g1
# 4                 ca          mb          manitoba  r3l 2t7

# %% [markdown]
# At this moment, the phone numbers in the facebook dataset were converted from object type (1.613832e+10) to string type (16138318840.0) so I need to get rid of the decimal before removing punctuation, otherwise all phone numbers will be 1 digit longer.

# %%
# remove decimal from phone number
fd['phone'] = fd['phone'].apply(lambda x: str(int(float(x))) if pd.notnull(x) else x)

fd.head()
# Out:
#                     domain                                            address  \
# 0       euro-hygiene-34.fr  134 rue entrepreneurs, za du vigné, 30420, cal...
# 1  lakesidehomeservices.ca                                               <NA>
# 2        rossiterboats.com                                               <NA>
# 3     caa-architecture.com  601 cordova st w # 270, v6b 1g1, vancouver, bc...
# 4            apexsurety.ca  unit 3 - 4 donald street, r3l 2t7, winnipeg, m...
#
#                                             category       city country_code  \
# 0                                               <NA>  calvisson           fr
# 1  appliance repair & maintenance|home builders &...       <NA>           ca
# 2        boats & yachts dealers|boat tours & cruises       <NA>         <NA>
# 3  architects & architectural services|other engi...  vancouver           ca
# 4                                               <NA>   winnipeg           ca
#
#   country                                        description  \
# 0  france                                               <NA>
# 1    <NA>                                               <NA>
# 2    <NA>  at rossiter boats we build semi-custom power b...
# 3  canada                                               <NA>
# 4  canada                                               <NA>
#
#                         email                             link  \
# 0                        <NA>       https://euro-hygiene-34.fr
# 1                        <NA>  https://lakesidehomeservices.ca
# 2      info@rossiterboats.com         http://rossiterboats.com
# 3  office@caa-arcitecture.com      http://caa-architecture.com
# 4                        <NA>            https://apexsurety.ca
#
#                                     name      page_type        phone  \
# 0                           euro hygiène  localbusiness         <NA>
# 1                 lakeside home services  localbusiness  16138318840
# 2                         rossiter boats  localbusiness         <NA>
# 3  chandler associates architecture inc.  localbusiness  16046873390
# 4           apex surety & insurance ltd.  localbusiness  12045602508
#
#   phone_country_code region_code            region zip_code
# 0               <NA>         occ         occitanie    30420
# 1                 ca        <NA>              <NA>     <NA>
# 2               <NA>        <NA>              <NA>     <NA>
# 3                 ca          bc  british columbia  v6b 1g1
# 4                 ca          mb          manitoba  r3l 2t7

# %% [markdown]
# At this moment I would like to remove punctuation but there is a catch! Usually, the pipe symbol ("|"), slash symbol ("/") and dash ("-") separate leading/ending letters so they do not have spaces before and after. Removing them would result in concatenating words which in case of 'category' column would not be ideal (in case of 'details' column it is not really relevant). The solution would be to replace any punctuation or special character with a white space. At the end I will strip all extra spaces.
#
# I will remove punctuation only where I find it necessary: address, category, phone, city and name of the company (only on common columns that will be later used at merging the datasets).

# %%
# remove punctuation

import string
import re

# choose columns to remove punctuation from
cols_to_clean_gd = ['address', 'category', 'name', 'phone', 'city']
cols_to_clean_fd = ['address', 'category', 'name', 'phone', 'city']
cols_to_clean_wd = ['legal_name', 'phone', 'name', 'category', 'city']

# translation table that maps every punctuation character to None
punctuation_pattern = '[{}]'.format(re.escape(string.punctuation))

# replace punctuation with white space
for col in cols_to_clean_gd:
    gd[col] = gd[col].str.replace(punctuation_pattern, ' ', regex=True)
    
for col in cols_to_clean_fd:
    fd[col] = fd[col].str.replace(punctuation_pattern, ' ', regex=True)

for col in cols_to_clean_wd:
    wd[col] = wd[col].str.replace(punctuation_pattern, ' ', regex=True)

fd.head()
# Out:
#                     domain                                            address  \
# 0       euro-hygiene-34.fr  134 rue entrepreneurs  za du vigné  30420  cal...
# 1  lakesidehomeservices.ca                                               <NA>
# 2        rossiterboats.com                                               <NA>
# 3     caa-architecture.com  601 cordova st w   270  v6b 1g1  vancouver  bc...
# 4            apexsurety.ca  unit 3   4 donald street  r3l 2t7  winnipeg  m...
#
#                                             category       city country_code  \
# 0                                               <NA>  calvisson           fr
# 1  appliance repair   maintenance home builders  ...       <NA>           ca
# 2        boats   yachts dealers boat tours   cruises       <NA>         <NA>
# 3  architects   architectural services other engi...  vancouver           ca
# 4                                               <NA>   winnipeg           ca
#
#   country                                        description  \
# 0  france                                               <NA>
# 1    <NA>                                               <NA>
# 2    <NA>  at rossiter boats we build semi-custom power b...
# 3  canada                                               <NA>
# 4  canada                                               <NA>
#
#                         email                             link  \
# 0                        <NA>       https://euro-hygiene-34.fr
# 1                        <NA>  https://lakesidehomeservices.ca
# 2      info@rossiterboats.com         http://rossiterboats.com
# 3  office@caa-arcitecture.com      http://caa-architecture.com
# 4                        <NA>            https://apexsurety.ca
#
#                                     name      page_type        phone  \
# 0                           euro hygiène  localbusiness         <NA>
# 1                 lakeside home services  localbusiness  16138318840
# 2                         rossiter boats  localbusiness         <NA>
# 3  chandler associates architecture inc   localbusiness  16046873390
# 4           apex surety   insurance ltd   localbusiness  12045602508
#
#   phone_country_code region_code            region zip_code
# 0               <NA>         occ         occitanie    30420
# 1                 ca        <NA>              <NA>     <NA>
# 2               <NA>        <NA>              <NA>     <NA>
# 3                 ca          bc  british columbia  v6b 1g1
# 4                 ca          mb          manitoba  r3l 2t7

# %%
# install cleanco library to remove company suffix
# !pip install cleanco
# Out:
# Collecting cleanco
#   Downloading cleanco-2.2-py3-none-any.whl.metadata (3.4 kB)
# Downloading cleanco-2.2-py3-none-any.whl (11 kB)
# Installing collected packages: cleanco
# Successfully installed cleanco-2.2

# %%
# remove company suffix (inc/ltd/co/srl etc)
from cleanco import basename

gd['name'] = gd['name'].apply(lambda x: basename(x) if isinstance(x, str) else x)
fd['name'] = fd['name'].apply(lambda x: basename(x) if isinstance(x, str) else x)
wd['name'] = wd['name'].apply(lambda x: basename(x) if isinstance(x, str) else x)
wd['legal_name'] = wd['legal_name'].apply(lambda x: basename(x) if isinstance(x, str) else x)

# remove all spaces in phone numbers
gd['phone'] = gd['phone'].str.replace(' ', '', regex=True)
fd['phone'] = fd['phone'].str.replace(' ', '', regex=True)
wd['phone'] = wd['phone'].str.replace(' ', '', regex=True)

fd.head()
# Out:
#                     domain                                            address  \
# 0       euro-hygiene-34.fr  134 rue entrepreneurs  za du vigné  30420  cal...
# 1  lakesidehomeservices.ca                                               <NA>
# 2        rossiterboats.com                                               <NA>
# 3     caa-architecture.com  601 cordova st w   270  v6b 1g1  vancouver  bc...
# 4            apexsurety.ca  unit 3   4 donald street  r3l 2t7  winnipeg  m...
#
#                                             category       city country_code  \
# 0                                               <NA>  calvisson           fr
# 1  appliance repair   maintenance home builders  ...       <NA>           ca
# 2        boats   yachts dealers boat tours   cruises       <NA>         <NA>
# 3  architects   architectural services other engi...  vancouver           ca
# 4                                               <NA>   winnipeg           ca
#
#   country                                        description  \
# 0  france                                               <NA>
# 1    <NA>                                               <NA>
# 2    <NA>  at rossiter boats we build semi-custom power b...
# 3  canada                                               <NA>
# 4  canada                                               <NA>
#
#                         email                             link  \
# 0                        <NA>       https://euro-hygiene-34.fr
# 1                        <NA>  https://lakesidehomeservices.ca
# 2      info@rossiterboats.com         http://rossiterboats.com
# 3  office@caa-arcitecture.com      http://caa-architecture.com
# 4                        <NA>            https://apexsurety.ca
#
#                                name      page_type        phone  \
# 0                      euro hygiène  localbusiness         <NA>
# 1            lakeside home services  localbusiness  16138318840
# 2                    rossiter boats  localbusiness         <NA>
# 3  chandler associates architecture  localbusiness  16046873390
# 4             apex surety insurance  localbusiness  12045602508
#
#   phone_country_code region_code            region zip_code
# 0               <NA>         occ         occitanie    30420
# 1                 ca        <NA>              <NA>     <NA>
# 2               <NA>        <NA>              <NA>     <NA>
# 3                 ca          bc  british columbia  v6b 1g1
# 4                 ca          mb          manitoba  r3l 2t7

# %%
# remove leading and trailing spaces
gd = gd.map(lambda x: x.strip() if isinstance(x, str) else x)
fd = fd.map(lambda x: x.strip() if isinstance(x, str) else x)
wd = wd.map(lambda x: x.strip() if isinstance(x, str) else x)

# remove extra spaces within string
gd = gd.map(lambda x: ' '.join(x.split()) if isinstance(x, str) else x)
fd = fd.map(lambda x: ' '.join(x.split()) if isinstance(x, str) else x)
wd = wd.map(lambda x: ' '.join(x.split()) if isinstance(x, str) else x)

# %% [markdown]
# The last thing I would like to do is to remove accents and handle special characters. While going through the datasets, I saw that it includes non-ASCII characters (like chinese alphabet) as well, so I would like to keep those intact.

# %%
# remove accents but keep non-ASCII characters from other languages

import unicodedata

def strip_accents(text):
    if pd.isna(text):
        # The value is NaN, return it as is
        return text
    else:
        # Normalize the text to decompose accented characters
        text = unicodedata.normalize('NFD', text)
        # Keep only characters that do not have a combining mark
        text = ''.join(c for c in text if unicodedata.combining(c) == 0)
        return str(text)

# apply the function to certain columns
cols_to_clean = ['address', 'category', 'name']

for col in cols_to_clean:
    gd[col] = gd[col].apply(strip_accents)
    fd[col] = fd[col].apply(strip_accents)
    
for col in cols_to_clean[1:3]:
    wd[col] = wd[col].apply(strip_accents)
    
fd.head()
# Out:
#                     domain                                            address  \
# 0       euro-hygiene-34.fr  134 rue entrepreneurs za du vigne 30420 calvis...
# 1  lakesidehomeservices.ca                                               <NA>
# 2        rossiterboats.com                                               <NA>
# 3     caa-architecture.com  601 cordova st w 270 v6b 1g1 vancouver bc cana...
# 4            apexsurety.ca  unit 3 4 donald street r3l 2t7 winnipeg mb can...
#
#                                             category       city country_code  \
# 0                                               <NA>  calvisson           fr
# 1  appliance repair maintenance home builders ren...       <NA>           ca
# 2            boats yachts dealers boat tours cruises       <NA>         <NA>
# 3  architects architectural services other engine...  vancouver           ca
# 4                                               <NA>   winnipeg           ca
#
#   country                                        description  \
# 0  france                                               <NA>
# 1    <NA>                                               <NA>
# 2    <NA>  at rossiter boats we build semi-custom power b...
# 3  canada                                               <NA>
# 4  canada                                               <NA>
#
#                         email                             link  \
# 0                        <NA>       https://euro-hygiene-34.fr
# 1                        <NA>  https://lakesidehomeservices.ca
# 2      info@rossiterboats.com         http://rossiterboats.com
# 3  office@caa-arcitecture.com      http://caa-architecture.com
# 4                        <NA>            https://apexsurety.ca
#
#                                name      page_type        phone  \
# 0                      euro hygiene  localbusiness         <NA>
# 1            lakeside home services  localbusiness  16138318840
# 2                    rossiter boats  localbusiness         <NA>
# 3  chandler associates architecture  localbusiness  16046873390
# 4             apex surety insurance  localbusiness  12045602508
#
#   phone_country_code region_code            region zip_code
# 0               <NA>         occ         occitanie    30420
# 1                 ca        <NA>              <NA>     <NA>
# 2               <NA>        <NA>              <NA>     <NA>
# 3                 ca          bc  british columbia  v6b 1g1
# 4                 ca          mb          manitoba  r3l 2t7

# %% [markdown]
# Now I would like to check if non-ASCII characters where left unchanged by using an example from the facebook dataset.

# %%
value = '寶血女子中學'
print(fd.loc[fd['name'] == value])
# Out:
#           domain                                       address  \
# 233  pbss.edu.hk  柴灣新廈街338號 0000 hong kong hong kong hong kong
#
#                category  city country_code    country description email  \
# 233  elementary schools  <NA>           hk  hong kong        <NA>  <NA>
#
#                     link    name     page_type phone phone_country_code  \
# 233  https://pbss.edu.hk  寶血女子中學  organization  <NA>               <NA>
#
#     region_code region zip_code
# 233        <NA>   <NA>     <NA>

# %% [markdown]
# # Step 3: Exploratory Data Analysis
#
# Now that all important data is uniform I can explore the datasets as follows:
# - check duplicates and null values
# - decide to keep or remove duplicates (based on the column)
# - decide which are the best columns to use when joining
#
# The best columns to use when joining should be the ones that have the most unique values and a low count of null values (preferably none).

# %%
print(f"The shape of the google dataset is: {gd.shape} (total entries, total columns)")
print(f"The shape of the facebook dataset is: {fd.shape}")
print(f"The shape of the website dataset is: {wd.shape}")
# Out:
# The shape of the google dataset is: (346925, 15) (total entries, total columns)
# The shape of the facebook dataset is: (71167, 16)
# The shape of the website dataset is: (72018, 11)

# %% [markdown]
# I found that the Google dataset had by far the most total entries. The Facebook and Website datasets had a very similar number of total entries.
#
# Next, let's check null values and unique values. I will put all 3 datasets one next to the other for an easier comparison.

# %%
# calculate number of unique values for each dataset
isnull_gd = gd.isnull().sum()
isnull_fd = fd.isnull().sum()
isnull_wd = wd.isnull().sum()

# concatenate the results into a single DataFrame
result1 = pd.concat([isnull_gd, isnull_fd, isnull_wd], axis=1)

# change display option
pd.options.display.float_format = '{:.0f}'.format

# rename the columns
result1.columns = ['Google', 'Facebook', 'Website']

print(f"The sum of null values for each column:\n\n{result1}")
# Out:
# The sum of null values for each column:
#
#                     Google  Facebook  Website
# address              25610     14477      NaN
# category             51063     16574     1384
# city                 44726     26600    11052
# country_code         51564     13976      NaN
# country              44690     26302     7149
# name                    32         0     3304
# phone                32136     26818     6378
# phone_country_code  112821     33616      NaN
# raw_address          44016       NaN      NaN
# raw_phone            27948       NaN      NaN
# region_code          44876     26605      NaN
# region               44871     26605    11085
# details               3514       NaN      NaN
# zip_code             81279     35544      NaN
# domain                   2         0        1
# description            NaN     43978      NaN
# email                  NaN     51414      NaN
# link                   NaN         0      NaN
# page_type              NaN         4      NaN
# domain_suffix          NaN       NaN      118
# language               NaN       NaN     5192
# legal_name             NaN       NaN    40029
# tld                    NaN       NaN      261

# %%
# calculate number of unique values for each dataset
nunique_gd = gd.nunique()
nunique_fd = fd.nunique()
nunique_wd = wd.nunique()

# concatenate the results into a single DataFrame
result2 = pd.concat([nunique_gd, nunique_fd, nunique_wd], axis=1)

# change display option
pd.options.display.float_format = '{:.0f}'.format

# rename the columns
result2.columns = ['Google', 'Facebook', 'Website']

print(f"The sum of unique values for each column:\n\n{result2}")
# Out:
# The sum of unique values for each column:
#
#                     Google  Facebook  Website
# address             274317     56357      NaN
# category               468     10073      562
# city                 22048      6325     9594
# country_code           213       130      NaN
# country                187       116      223
# name                338305     70950    67394
# phone               277563     44272    60053
# phone_country_code     212       100      NaN
# raw_address         137626       NaN      NaN
# raw_phone           284780       NaN      NaN
# region_code            678       434      NaN
# region                1502       681     1114
# details             339455       NaN      NaN
# zip_code            100697     25958      NaN
# domain               70109     71167    72017
# description            NaN     26807      NaN
# email                  NaN     19745      NaN
# link                   NaN     71167      NaN
# page_type              NaN         4      NaN
# domain_suffix          NaN       NaN      667
# language               NaN       NaN       70
# legal_name             NaN       NaN    30402
# tld                    NaN       NaN      293

# %% [markdown]
# At the moment, we can make the following statements:
# 1. 'domain' and 'name' columns are the ones that have the least amount of null values in all 3 datasets, which is an important aspect when joining datasets. 'domain' is the winner for now.
# 2. Values in 'domain' column in website dataset are all unique (except 1 null value).
# 3. Values in 'domain' column in facebook dataset are all unique.
# 4. Google dataset has a lot of duplicates in 'domain' column so for this particular dataset maybe we need to find another identification key. The 'name' column has the biggest amount of unique values.
#
# In website dataset there are 2 columns that represent the name of the company: the legal name and the site name (most used/known). To decrease the number of null values in 'name' column (3304 at the moment), I decided to copy the values from 'legal_name' to 'name' if 'name' value is null. I do this because I intend to use 'name' column as merge column later on.

# %%
initial_null_names_count = wd['name'].isnull().sum()

# copy 'legal_name' values to 'name' values if 'name' value is null
wd['name'] = wd['name'].combine_first(wd['legal_name'])

print(f"Let's see if the number of null values in 'name' column decreased: {wd['name'].isnull().sum()} versus {initial_null_names_count} (initial).")
# Out:
# Let's see if the number of null values in 'name' column decreased: 2619 versus 3304 (initial).

# %% [markdown]
# A bit better I would say!
#
# Next step: check duplicates and decide whether they should be kept or removed. I will start by checking the 'domain' column first for all 3 datasets. As we know so far, website and facebook datasets do not have duplicates in this column so I will check only the google dataset.

# %%
# check duplicates in 'domain' column in google dataset
duplicate_counts_domain_gd = gd['domain'].value_counts()
duplicate_counts_domain_gd = duplicate_counts_domain_gd[duplicate_counts_domain_gd > 1]

print(duplicate_counts_domain_gd)
# Out:
# domain
# facebook.com                 69465
# postoffice.co.uk              5872
# instagram.com                 5463
# ihg.com                       4192
# marriott.com                  3816
#                              ...
# cliniqueauditivebougie.ca        2
# polarvision.ca                   2
# montserrat.edu                   2
# nextflightcourier.com            2
# artisansofmedicine.com           2
# Name: count, Length: 14987, dtype: int64

# %% [markdown]
# Now we can clearly see that the google dataset has a ton of duplicates in the 'domain' column. Even though there are many duplicates, the entries seem to represent different companies. For example, many companies may have 'facebook.com' as their domain.
#
# Let's check how many duplicates does the 'name' column have.

# %%
# check duplicates in 'name' column in google dataset
duplicate_counts_name_gd = gd['name'].value_counts()
duplicate_counts_name_gd = duplicate_counts_name_gd[duplicate_counts_name_gd > 1]

print(duplicate_counts_name_gd)
# Out:
# name
# lincoln elementary school                      21
# transportation department                      16
# city hall                                      15
# washington elementary school                   15
# atm                                            14
#                                                ..
# meridian development                            2
# heart to home meals                             2
# st paul s lutheran church school                2
# home instead familien und seniorenbetreuung     2
# central home realty                             2
# Name: count, Length: 6260, dtype: int64

# %% [markdown]
# Strange...let's see if they represent the same companies!

# %%
# check the address for every company that has the same name
address = gd.loc[gd['name'] == 'lincoln elementary school', 'address']
print(address)
# Out:
# 21504                    705 california st salinas ca 93901
# 46528                           701 5th ave dayton ky 41074
# 74484     712 lincoln ave ridgefield park nj 07660 unite...
# 75549     746 n maple grove ave hudson mi 49247 united s...
# 82063                         1812 cron st augusta ks 67010
# 117536                         1725 13th st gering ne 69341
# 147761                 15615 clifton blvd lakewood oh 44107
# 170635                          930 s sirrine mesa az 85210
# 173041                66 bartlett st new brunswick nj 08901
# 200356                    300 teeters ct iowa city ia 52246
# 205755                  501 s euclid ave princeton il 61356
# 206942                 720 s franklin ave hastings ne 68901
# 212697                                   sault ste marie mi
# 221379                    600 5th ave charles city ia 50616
# 261957                 3312 n douglas ave loveland co 80538
# 262716                    60 e lincoln ave zeeland mi 49464
# 263050                         2120 9th st s fargo nd 58103
# 275677                          1111 main st pella ia 50219
# 277395                       101 lamine st lincoln mo 65338
# 279876                     2 ralston pl pittsburgh pa 15216
# 304288                      10280 n 450 e de motte in 46310
# Name: address, dtype: object

# %% [markdown]
# Same name for 21 different companies. Now we know that we cannot remove 'name' duplicates that easily. In this case, when joining, there will be some extra conditions (ex: name + city).
#
# This might be a good time to drop any full duplicates.

# %%
# count and drop duplicates
original_length_gd = len(gd)
original_length_fd = len(fd)
original_length_wd = len(wd)

# print duplicates before dropping
print("Duplicates in google dataset:")
print(gd[gd.duplicated()])
print("\n\nDuplicates in facebook dataset:")
print(fd[fd.duplicated()])
print("\n\nDuplicates in website dataset:")
print(wd[wd.duplicated()])

gd = gd.drop_duplicates()
fd = fd.drop_duplicates()
wd = wd.drop_duplicates()

new_length_gd = len(gd)
new_length_fd = len(fd)
new_length_wd = len(wd)

num_duplicates_gd = original_length_gd - new_length_gd
num_duplicates_fd = original_length_fd - new_length_fd
num_duplicates_wd = original_length_wd - new_length_wd

print(f"\n\nNumber of duplicates dropped in google dataset: {num_duplicates_gd}")
print(f"Number of duplicates dropped in facebook dataset: {num_duplicates_fd}")
print(f"Number of duplicates dropped in website dataset: {num_duplicates_wd}")
# Out:
# Duplicates in google dataset:
#                                                   address  \
# 84383   133 high st bitton bristol bs30 6hq united kin...
# 137349  551 rue saint georges saint jerome qc j7z 5b7 ...
# 165571         10101 111 st nw edmonton ab t5k 1k6 canada
# 195938          20420 hwy 11 s bradford on l3z 2b7 canada
# 226386                                               <NA>
# 244335  2727 n holland sylvania rd k toledo oh 43615 u...
# 271954         10107 111 st nw edmonton ab t5k 2z1 canada
# 301204                                               <NA>
# 327540                                               <NA>
# 328942                                               <NA>
# 336727         10103 111 st nw edmonton ab t5k 2y1 canada
#
#                                          category          city country_code  \
# 84383                                        <NA>       bristol           gb
# 137349                     malls shopping centers  saint jerome           ca
# 165571                      nursing personal care      edmonton           ca
# 195938                    auto parts repair shops      bradford           ca
# 226386                                       <NA>          <NA>         <NA>
# 244335  investment consultants financial advisors        toledo           us
# 271954                      nursing personal care      edmonton           ca
# 301204                real estate agents managers          <NA>           fr
# 327540                                       <NA>          <NA>         <NA>
# 328942                                       <NA>          <NA>         <NA>
# 336727                      nursing personal care      edmonton           ca
#
#                country                                               name  \
# 84383   united kingdom                   premier bitton convenience store
# 137349          canada  encore eco boutique ecologique zero dechet pro...
# 165571          canada                rosedale seniors living the estates
# 195938          canada                                       napa autopro
# 226386            <NA>                                     finansbank atm
# 244335   united states       suzanne martin ameriprise financial services
# 271954          canada                  rosedale seniors living the villa
# 301204            <NA>                           julien bellet iad france
# 327540            <NA>                      biomerieux campus de l etoile
# 328942            <NA>                                              emaar
# 336727          canada                   rosedale seniors living the park
#
#                phone phone_country_code  \
# 84383   441179321990                 gb
# 137349   14503042669                 ca
# 165571   17807090728                 ca
# 195938   19057757876                 ca
# 226386          <NA>               <NA>
# 244335   14197259223                 us
# 271954   17807090728                 ca
# 301204   33788286084                 fr
# 327540          <NA>               <NA>
# 328942          <NA>               <NA>
# 336727   17807090728                 ca
#
#                                               raw_address          raw_phone  \
# 84383          bristol, united kingdom · +44 117 932 1990   +44 117 932 1990
# 137349                                               <NA>    +1 450-304-2669
# 165571                               edmonton, ab, canada    +1 780-709-0728
# 195938                               bradford, on, canada    +1 905-775-7876
# 226386                                               <NA>               <NA>
# 244335  3+ years in business · 2727 n holland sylvania...    +1 419-725-9223
# 271954                               edmonton, ab, canada    +1 780-709-0728
# 301204                                               <NA>  +33 7 88 28 60 84
# 327540                                               <NA>               <NA>
# 328942                                               <NA>               <NA>
# 336727                               edmonton, ab, canada    +1 780-709-0728
#
#        region_code   region  \
# 84383          eng  england
# 137349          qc   quebec
# 165571          ab  alberta
# 195938          on  ontario
# 226386        <NA>     <NA>
# 244335          oh     ohio
# 271954          ab  alberta
# 301204        <NA>     <NA>
# 327540        <NA>     <NA>
# 328942        <NA>     <NA>
# 336727          ab  alberta
#
#                                                   details  zip_code  \
# 84383   convenience store bristol, united kingdom · +4...  bs30 6hq
# 137349  5.0 (19) · general store 551 rue saint georges...   j7z 5b7
# 165571  no reviews · assisted living facility edmonton...   t5k 1k6
# 195938  no reviews · auto repair shop bradford, on, ca...   l3z 2b7
# 226386                                               <NA>      <NA>
# 244335  no reviews · financial planner 3+ years in bus...     43615
# 271954  3.0 (4) · assisted living facility edmonton, a...   t5k 2z1
# 301204  no reviews · real estate consultant +33 7 88 2...      <NA>
# 327540                                               <NA>      <NA>
# 328942                                               <NA>      <NA>
# 336727  no reviews · assisted living facility edmonton...   t5k 2y1
#
#                            domain
# 84383        premier-stores.co.uk
# 137349                encoreco.ca
# 165571  rosedaleseniorsliving.com
# 195938            napaautopro.com
# 226386          qnbfinansbank.com
# 244335     ameripriseadvisors.com
# 271954  rosedaleseniorsliving.com
# 301204               iadfrance.fr
# 327540             biomerieux.com
# 328942                  emaar.com
# 336727  rosedaleseniorsliving.com
#
#
# Duplicates in facebook dataset:
# Empty DataFrame
# Columns: [domain, address, category, city, country_code, country, description, email, link, name, page_type, phone, phone_country_code, region_code, region, zip_code]
# Index: []
#
#
# Duplicates in website dataset:
# Empty DataFrame
# Columns: [domain, domain_suffix, language, legal_name, city, country, region, phone, name, tld, category]
# Index: []
#
#
# Number of duplicates dropped in google dataset: 11
# Number of duplicates dropped in facebook dataset: 0
# Number of duplicates dropped in website dataset: 0

# %% [markdown]
# Perfect! The last thing I would like to do to the google dataset is to check if the duplicates are valid duplicates or maybe I did something wrong on the way :O I will check them by 'raw_phone' column because it has the least amount of null values and it is one of the few columns I left unchanged by now :)
#
# I took all raw phone numbers from the duplicates found and checked them in the original google dataset (a copy of it).

# %%
# choose values from 'raw_phone' column to check duplicates
phones = ['+44 117 932 1990', '+1 450-304-2669', '+1 780-709-0728', '+1 905-775-7876', '+1 419-725-9223', '+33 7 88 28 60 84']

# print lines that contain the phone values
print("Lines in google dataset that contain the raw_phone values (separated by dashes):")
for phone in phones:
    print(gd_copy[gd_copy['raw_phone'] == phone])
    print('-' * 100)
# Out:
# Lines in google dataset that contain the raw_phone values (separated by dashes):
#                                                  address category     city  \
# 67278  133 High St, Bitton, Bristol BS30 6HQ, United ...      NaN  bristol
# 84383  133 High St, Bitton, Bristol BS30 6HQ, United ...      NaN  bristol
#
#       country_code    country_name                                name  \
# 67278           gb  united kingdom  Premier - Bitton Convenience Store
# 84383           gb  united kingdom   Premier- Bitton Convenience Store
#
#                phone phone_country_code  \
# 67278  +441179321990                 gb
# 84383  +441179321990                 gb
#
#                                       raw_address         raw_phone  \
# 67278  Bristol, United Kingdom · +44 117 932 1990  +44 117 932 1990
# 84383  Bristol, United Kingdom · +44 117 932 1990  +44 117 932 1990
#
#       region_code region_name  \
# 67278         eng     england
# 84383         eng     england
#
#                                                     text  zip_code  \
# 67278  Convenience store Bristol, United Kingdom · +4...  bs30 6hq
# 84383  Convenience store Bristol, United Kingdom · +4...  bs30 6hq
#
#                      domain
# 67278  premier-stores.co.uk
# 84383  premier-stores.co.uk
# ----------------------------------------------------------------------------------------------------
#                                                   address  \
# 3611    551 Rue Saint Georges, Saint-Jérôme, QC J7Z 5B...
# 137349  551 Rue Saint Georges, Saint-Jérôme, QC J7Z 5B...
#
#                         category          city country_code country_name  \
# 3611    Malls & Shopping Centers  saint-jerome           ca       canada
# 137349  Malls & Shopping Centers  saint-jerome           ca       canada
#
#                                                      name         phone  \
# 3611    Encore eco - boutique écologique, zéro déchet,...  +14503042669
# 137349  Encore éco - boutique écologique, zéro déchet,...  +14503042669
#
#        phone_country_code raw_address        raw_phone region_code  \
# 3611                   ca         NaN  +1 450-304-2669          qc
# 137349                 ca         NaN  +1 450-304-2669          qc
#
#        region_name                                               text  \
# 3611        quebec  5.0 (19) · General store 551 Rue Saint Georges...
# 137349      quebec  5.0 (19) · General store 551 Rue Saint Georges...
#
#        zip_code       domain
# 3611    j7z 5b7  encoreco.ca
# 137349  j7z 5b7  encoreco.ca
# ----------------------------------------------------------------------------------------------------
#                                               address  \
# 93439   10101 111 St NW, Edmonton, AB T5K 1K6, Canada
# 93440   10107 111 St NW, Edmonton, AB T5K 2Z1, Canada
# 121214  10103 111 St NW, Edmonton, AB T5K 2Y1, Canada
# 157238  10053 111 St NW, Edmonton, AB T5K 2H8, Canada
# 165571  10101 111 St NW, Edmonton, AB T5K 1K6, Canada
# 271954  10107 111 St NW, Edmonton, AB T5K 2Z1, Canada
# 336727  10103 111 St NW, Edmonton, AB T5K 2Y1, Canada
#
#                        category      city country_code country_name  \
# 93439   Nursing & Personal Care  edmonton           ca       canada
# 93440   Nursing & Personal Care  edmonton           ca       canada
# 121214  Nursing & Personal Care  edmonton           ca       canada
# 157238  Nursing & Personal Care  edmonton           ca       canada
# 165571  Nursing & Personal Care  edmonton           ca       canada
# 271954  Nursing & Personal Care  edmonton           ca       canada
# 336727  Nursing & Personal Care  edmonton           ca       canada
#
#                                           name         phone  \
# 93439    Rosedale Seniors Living - The Estates  +17807090728
# 93440      Rosedale Seniors Living - The Villa  +17807090728
# 121214      Rosedale Seniors Living - The Park  +17807090728
# 157238     Rosedale Seniors Living - The Manor  +17807090728
# 165571  Rosedale Seniors' Living - The Estates  +17807090728
# 271954    Rosedale Seniors' Living - The Villa  +17807090728
# 336727     Rosedale Seniors' Living - The Park  +17807090728
#
#        phone_country_code           raw_address        raw_phone region_code  \
# 93439                  ca  Edmonton, AB, Canada  +1 780-709-0728          ab
# 93440                  ca  Edmonton, AB, Canada  +1 780-709-0728          ab
# 121214                 ca  Edmonton, AB, Canada  +1 780-709-0728          ab
# 157238                 ca  Edmonton, AB, Canada  +1 780-709-0728          ab
# 165571                 ca  Edmonton, AB, Canada  +1 780-709-0728          ab
# 271954                 ca  Edmonton, AB, Canada  +1 780-709-0728          ab
# 336727                 ca  Edmonton, AB, Canada  +1 780-709-0728          ab
#
#        region_name                                               text  \
# 93439      alberta  No reviews · Assisted living facility Edmonton...
# 93440      alberta  3.0 (4) · Assisted living facility Edmonton, A...
# 121214     alberta  No reviews · Assisted living facility Edmonton...
# 157238     alberta  5.0 (3) · Assisted living facility Edmonton, A...
# 165571     alberta  No reviews · Assisted living facility Edmonton...
# 271954     alberta  3.0 (4) · Assisted living facility Edmonton, A...
# 336727     alberta  No reviews · Assisted living facility Edmonton...
#
#        zip_code                     domain
# 93439   t5k 1k6  rosedaleseniorsliving.com
# 93440   t5k 2z1  rosedaleseniorsliving.com
# 121214  t5k 2y1  rosedaleseniorsliving.com
# 157238  t5k 2h8  rosedaleseniorsliving.com
# 165571  t5k 1k6  rosedaleseniorsliving.com
# 271954  t5k 2z1  rosedaleseniorsliving.com
# 336727  t5k 2y1  rosedaleseniorsliving.com
# ----------------------------------------------------------------------------------------------------
#                                              address  \
# 119794  20420 Hwy 11 S, Bradford, ON L3Z 2B7, Canada
# 195938  20420 Hwy 11 S, Bradford, ON L3Z 2B7, Canada
#
#                          category      city country_code country_name  \
# 119794  Auto Parts & Repair Shops  bradford           ca       canada
# 195938  Auto Parts & Repair Shops  bradford           ca       canada
#
#                 name         phone phone_country_code           raw_address  \
# 119794  napa autopro  +19057757876                 ca  Bradford, ON, Canada
# 195938  NAPA AUTOPRO  +19057757876                 ca  Bradford, ON, Canada
#
#               raw_phone region_code region_name  \
# 119794  +1 905-775-7876          on     ontario
# 195938  +1 905-775-7876          on     ontario
#
#                                                      text zip_code  \
# 119794  No reviews · Auto repair shop Bradford, ON, Ca...  l3z 2b7
# 195938  No reviews · Auto repair shop Bradford, ON, Ca...  l3z 2b7
#
#                  domain
# 119794  napaautopro.com
# 195938  napaautopro.com
# ----------------------------------------------------------------------------------------------------
#                                                   address  \
# 202574  2727 N Holland Sylvania Rd # K, Toledo, OH 436...
# 244335  2727 N Holland Sylvania Rd # K, Toledo, OH 436...
#
#                                            category    city country_code  \
# 202574  Investment Consultants & Financial Advisors  toledo           us
# 244335  Investment Consultants & Financial Advisors  toledo           us
#
#          country_name                                               name  \
# 202574  united states  Suzanne Martin - Ameriprise Financial Services...
# 244335  united states  Suzanne Martin - Ameriprise Financial Services...
#
#                phone phone_country_code  \
# 202574  +14197259223                 us
# 244335  +14197259223                 us
#
#                                               raw_address        raw_phone  \
# 202574  3+ years in business · 2727 N Holland Sylvania...  +1 419-725-9223
# 244335  3+ years in business · 2727 N Holland Sylvania...  +1 419-725-9223
#
#        region_code region_name  \
# 202574          oh        ohio
# 244335          oh        ohio
#
#                                                      text zip_code  \
# 202574  No reviews · Financial planner 3+ years in bus...    43615
# 244335  No reviews · Financial planner 3+ years in bus...    43615
#
#                         domain
# 202574  ameripriseadvisors.com
# 244335  ameripriseadvisors.com
# ----------------------------------------------------------------------------------------------------
#        address                         category city country_code  \
# 214763     NaN  Real Estate - Agents & Managers  NaN           fr
# 301204     NaN  Real Estate - Agents & Managers  NaN           fr
#
#        country_name                        name         phone  \
# 214763          NaN    Julien Bellet IAD France  +33788286084
# 301204          NaN  Julien BELLET - Iad France  +33788286084
#
#        phone_country_code raw_address          raw_phone region_code  \
# 214763                 fr         NaN  +33 7 88 28 60 84         NaN
# 301204                 fr         NaN  +33 7 88 28 60 84         NaN
#
#        region_name                                               text  \
# 214763         NaN  No reviews · Real estate consultant +33 7 88 2...
# 301204         NaN  No reviews · Real estate consultant +33 7 88 2...
#
#        zip_code        domain
# 214763      NaN  iadfrance.fr
# 301204      NaN  iadfrance.fr
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Huh! Great news! By removing special characters, accents, extra spaces and by converting everything to lowercase, we found some duplicates (11). It means that the data is on good hands :)
#
# Next I am going through the same process with the facebook and website dataset: check duplicates and decide on keeping/removing them. Keep in mind that 'domain' values are unique so probably I am not going to remove anything.

# %%
# check duplicates in 'name' column in facebook dataset
duplicate_counts_name_fd = fd['name'].value_counts()
duplicate_counts_name_fd = duplicate_counts_name_fd[duplicate_counts_name_fd > 1]

print(duplicate_counts_name_fd)
# Out:
# name
# nissan                                 7
# hilti                                  6
# little learners preschool              4
# grace christian school                 4
# jll                                    4
#                                       ..
# sacred heart catholic school           2
# city of neodesha                       2
# absolute contracting                   2
# our lady of victory catholic school    2
# cornerstone assembly of god            2
# Name: count, Length: 173, dtype: int64

# %%
# check the domain for every company that has the same name
nissan_domains = fd.loc[fd['name'] == 'nissan', 'domain']
print(nissan_domains)
# Out:
# 27521    nissan.com.tr
# 28728    nissan.com.hk
# 38564    nissan.com.mx
# 58699        nissan.ru
# 61938    nissan-me.com
# 65464     nissan.co.za
# 67170    nissan.com.au
# Name: domain, dtype: object

# %% [markdown]
# Despite having the same name, the companies are different because of the country in which they are located. No dropping here either!

# %%
# check duplicates in 'name' column in website dataset
duplicate_counts_name_wd = wd['name'].value_counts()
duplicate_counts_name_wd = duplicate_counts_name_wd[duplicate_counts_name_wd > 1]

print(duplicate_counts_name_wd)
# Out:
# name
# mysite                      69
#                             33
# the canadian real estate    27
# home                        26
# inmotion hosting            16
#                             ..
# mirvac                       2
# our lady of sorrows          2
# at a glance                  2
# april marine                 2
# cornerstone insurance        2
# Name: count, Length: 850, dtype: int64

# %%
# check the domain for every company that has the same name
mysite_domains = wd.loc[wd['name'] == 'mysite', 'domain']
print(mysite_domains)
# Out:
# 881               blackstackmechanical.ca
# 1501           performanceautocalgary.com
# 3077                 marinelifecanada.com
# 4827                      freshlookbl.com
# 5691             ontariolegalservices.com
#                        ...
# 69307    thechristiantabernaclechurch.com
# 69420                    dreamdenture.com
# 70949                        luvmydog.net
# 71059              connorstreeservice.com
# 71427                themetalmonkey.co.uk
# Name: domain, Length: 69, dtype: object

# %% [markdown]
# Last but not least, I will introduce index columns and suffixes for all columns in all 3 datasets. This is a prestep to make the join easier.

# %%
# add index column for each dataset
gd = gd.reset_index()
fd = fd.reset_index()
wd = wd.reset_index()

# add suffixes for all columns
gd = gd.add_suffix('_g')
fd = fd.add_suffix('_f')
wd = wd.add_suffix('_w')

# set index column for each dataset
gd.set_index('index_g', inplace=True)
fd.set_index('index_f', inplace=True)
wd.set_index('index_w', inplace=True)

# %% [markdown]
# # Step 4: Datasets join
#
# Now I am going to join the datasets. My plan is to first join the facebook and website datasets by the 'domain' column as it is the column that has the least amount of null values and the biggest amount of unique values for both datasets.
#
# Best method I encountered so far is using the Python Record Linkage Toolkit. This library has the capability to limit the pool of potential matches by using the so called blockers. In this way, by blocking the domain for each company, the number of matches will be significantly reduced. Having in mind only the common columns (country, city, region, name, phone, domain, category) I will choose only 4 of them to compare using the methods defined in the record linkage library. I will use an exact comparison for the columns that have exact values such as country, city and region. For the name column I will use a string similarity comparison, as the names can differ in many ways (abbreviations, different language, stop words etc). The method for the string similarity comparison that I will be using is jarowinkler. The threshold needs to be evaluated, but it surely needs to be on the higher edge. One important note: the way null values are proccessed needs to be adressed. In my case, the comparison between a null value and a non-null value must be true (score = 1) for any column or comparison method used. So only if the values that are compared are the same or one of them is null, that is the only time the score will be 1 for that position (row, column). In this way, the score for a match will be in a range from 0 to 4 (because it compares 4 columns) and I will take into consideration only the best scores (> 3).

# %%
# !pip install recordlinkage
# Out:
# Collecting recordlinkage
#   Downloading recordlinkage-0.16-py3-none-any.whl.metadata (8.1 kB)
# Collecting jellyfish>=1 (from recordlinkage)
#   Downloading jellyfish-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.13 in /opt/conda/lib/python3.10/site-packages (from recordlinkage) (1.26.4)
# Requirement already satisfied: pandas<3,>=1 in /opt/conda/lib/python3.10/site-packages (from recordlinkage) (2.2.1)
# Requirement already satisfied: scipy>=1 in /opt/conda/lib/python3.10/site-packages (from recordlinkage) (1.11.4)
# Requirement already satisfied: scikit-learn>=1 in /opt/conda/lib/python3.10/site-packages (from recordlinkage) (1.2.2)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from recordlinkage) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1->recordlinkage) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1->recordlinkage) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1->recordlinkage) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1->recordlinkage) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1->recordlinkage) (1.16.0)
# Downloading recordlinkage-0.16-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.9/926.9 kB 9.0 MB/s eta 0:00:00
# Downloading jellyfish-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.6 MB/s eta 0:00:00
# Installing collected packages: jellyfish, recordlinkage
# Successfully installed jellyfish-1.0.3 recordlinkage-0.16

# %%
import recordlinkage

# create indexer object to identify pairs of rows
indexer = recordlinkage.Index()

# apply blocking on 'domain_f' and 'domain_w'
indexer.block(left_on='domain_f', right_on='domain_w')

# generate candidate links
candidates = indexer.index(fd, wd)

print(f"Number of potential matches: {len(candidates)}")
# Out:
# Number of potential matches: 71162

# %% [markdown]
# As we can see, by blocking the domain column, the number of matches is very small compared with the total number of potential matches (nr. entries facebook * nr. entries website). We saved a lot of time and computational resources!
#
# Next I will compute the comparisons (4 columns -> 4 comparisons) and I will track the runtime to see how long it takes.

# %%
# create compare object
compare = recordlinkage.Compare()

# compare country exactly
compare.exact('country_f', 'country_w', label='country_score', missing_value=1)

# compare city exactly
compare.exact('city_f', 'city_w', label='city_score', missing_value=1)

# compare region exactly
compare.exact('region_f', 'region_w', label='region_score', missing_value=1)

# compare name using Jaro-Winkler similarity
compare.string('name_f',
            'name_w',
            method='jarowinkler',
            threshold=0.85,
            label='name_score',
            missing_value=1)

import time

# record start time
t = time.time()

# compute feature vectors for candidate links
features = compare.compute(candidates, fd, wd)

# calculate elapsed time
interval = time.time() - t

print(f"Computing time: {interval} seconds")
# Out:
# Computing time: 0.5570087432861328 seconds

# %% [markdown]
# The features dataframe should contain the index of the rows that matched (both facebook index and website index) and the score for each comparison. They are labeled country_score, city_score, region_score, name_score and they can take only 1 and 0 as values (true or false).

# %%
features.head()
# Out:
#                  country_score  city_score  region_score  name_score
# index_f index_w
# 0       64518                1           0             1           1
# 1       70546                1           1             1           1
# 2       14350                1           1             1           1
# 3       22282                1           1             1           1
# 4       66294                1           1             1           0

# %%
print(f"Score | Nr.of matches")

# sum features by score, count unique sums and sort in descending order
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# Score | Nr.of matches
# 4    48140
# 3    17245
# 2     2889
# 1     2282
# 0      606
# Name: count, dtype: int64

# %% [markdown]
# Now I have to decide with what score I will go further. Country, region and city should require exact matches such that companies located in different regions are treated as different companies. Name is the feature that is compared using similarity and in this case, a score of 0 would mean that the values are more different than similar, so probably not the same company either. Having this in mind, the score that I find most accurate will be score=4 which means 48.140 matches (from a total of 143.185 entries) from facebook and website dataset. This means that the match rate is around 67%. Looks good!
#
# Now we merge!!!

# %%
# filter rows where the sum along the row is greater than or equal to 4
filtered = features[features.sum(axis=1) >= 4] 

filtered.reset_index(inplace=True)

# merge 'filtered' and 'fd' on 'index_f', keeping all rows from both
merged = pd.merge(filtered, fd, left_on='index_f', right_index=True, how='outer')

# merge the resulting DataFrame with 'wd' on 'index_w', keeping all rows from both
merged = pd.merge(merged, wd, left_on='index_w', right_index=True, how='outer')

# merge common columns (_f and _w)
merged['city'] = merged['city_f'].combine_first(merged['city_w'])
merged['country'] = merged['country_f'].combine_first(merged['country_w'])
merged['region'] = merged['region_f'].combine_first(merged['region_w'])
merged['domain'] = merged['domain_f'].combine_first(merged['domain_w'])

# keep website 'phone' column (or facebook if website is null)
merged['phone'] = merged['phone_w'].fillna(merged['phone_f'])

# keep website 'name' column (or facebook if website is null)
merged['name'] = merged['name_w'].fillna(merged['name_f'])

# keep website 'category' column (or facebook if website is null)
merged['category'] = merged['category_w'].fillna(merged['category_f'])

# drop columns (_f and _w)
merged = merged.drop(['index_f', 'index_w', 'country_score', 'city_score', 'region_score', 'name_score',
                      'city_f', 'country_f', 'name_f', 'phone_f', 'region_f', 'category_f', 'domain_f',
                      'city_w', 'country_w', 'name_w', 'phone_w', 'region_w', 'category_w', 'domain_w' ], axis=1)

merged.head()
# Out:
#                                                address_f country_code_f  \
# 42751  246 brockport dr m9w 5s1 toronto on canada ont...             ca
# NaN                                                  NaN            NaN
# NaN                                                  NaN            NaN
# 44608  1395 riverside drive p4r 1a6 timmins on canada...             ca
# 34731       2256 vista oak rd oakville on canada ontario             ca
#
#                                            description_f  \
# 42751  converter man limited is a leader in torque co...
# NaN                                                  NaN
# NaN                                                  NaN
# 44608  timmins garage incorporated is a chevrolet, gm...
# 34731  destinate provides real-world, results-focused...
#
#                            email_f                    link_f    page_type_f  \
# 42751       peter@converterman.com   http://converterman.com  localbusiness
# NaN                            NaN                       NaN            NaN
# NaN                            NaN                       NaN            NaN
# 44608  contactus@timminsgarage.com  http://timminsgarage.com  localbusiness
# 34731            info@destinate.ca       http://destinate.ca   organization
#
#       phone_country_code_f region_code_f zip_code_f domain_suffix_w  \
# 42751                   ca          <NA>       <NA>            <NA>
# NaN                    NaN           NaN        NaN              ca
# NaN                    NaN           NaN        NaN          com.au
# 44608                 <NA>            on    p4r 1a6             com
# 34731                 <NA>            on       <NA>              ca
#
#       language_w                        legal_name_w tld_w      city  \
# 42751       <NA>                                <NA>  <NA>      <NA>
# NaN           en                                <NA>    ca  cardigan
# NaN           en  investa wholesale funds management    au  brisbane
# 44608         en                      timmins garage   com   timmins
# 34731         en                     destinate group    ca  oakville
#
#          country                region               domain        phone  \
# 42751       <NA>                  <NA>     converterman.com  14166747000
# NaN       canada  prince edward island  clothesencounter.ca  13066937766
# NaN    australia            queensland       investa.com.au  61282269300
# 44608     canada               ontario    timminsgarage.com  18775896640
# 34731     canada               ontario         destinate.ca  18662929696
#
#                          name                          category
# 42751           converter man          auto restoration service
# NaN         clothes encounter       shoes other footwear stores
# NaN    investa property group            real estate developers
# 44608          timmins garage  automobile dealers manufacturers
# 34731         destinate group               business consulting

# %%
# check if there are any lines that have null values in the domain column
null_rows = merged[merged['domain'].isnull()]
print(f"Number of entries with null domain: {len(null_rows)}\n")
print(null_rows)
# Out:
# Number of entries with null domain: 1
#
#     address_f country_code_f description_f email_f link_f page_type_f  \
# NaN       NaN            NaN           NaN     NaN    NaN         NaN
#
#     phone_country_code_f region_code_f zip_code_f domain_suffix_w language_w  \
# NaN                  NaN           NaN        NaN            <NA>       <NA>
#
#     legal_name_w tld_w  city country region domain phone name category
# NaN         <NA>  <NA>  <NA>    <NA>   <NA>   <NA>   NaN  NaN      NaN

# %% [markdown]
# We found 1 entry with null domain. It seems that all columns are null, so we will remove this entry.

# %%
# drop the column that was found above
merged = merged.dropna(subset=['domain'])

# rename columns, dataset and add index column (prepare for the next merge with google dataset)
merged.columns = ['adress', 'country_code', 'description', 'email', 'link', 'page_type',
                  'phone_country_code', 'region_code', 'zip_code', 'domain_suffix', 'language',
                  'legal_name', 'tld', 'city', 'country', 'region', 'domain', 'phone', 'name', 'category']
merged_f_w = merged.reset_index()
merged_f_w = merged_f_w.drop(['index'], axis=1) # remove the indexation made by the notebook???
merged_f_w = merged_f_w.reset_index()

# add suffixes to be easily distinguished (_f_w)
merged_f_w = merged_f_w.add_suffix('_f_w')

# set index column for the new dataset
merged_f_w.set_index('index_f_w', inplace=True)

merged_f_w[['city_f_w', 'country_f_w', 'region_f_w', 'domain_f_w', 'phone_f_w', 'name_f_w', 'category_f_w']].head()
# Out:
#            city_f_w country_f_w            region_f_w           domain_f_w  \
# index_f_w
# 0              <NA>        <NA>                  <NA>     converterman.com
# 1          cardigan      canada  prince edward island  clothesencounter.ca
# 2          brisbane   australia            queensland       investa.com.au
# 3           timmins      canada               ontario    timminsgarage.com
# 4          oakville      canada               ontario         destinate.ca
#
#              phone_f_w                name_f_w  \
# index_f_w
# 0          14166747000           converter man
# 1          13066937766       clothes encounter
# 2          61282269300  investa property group
# 3          18775896640          timmins garage
# 4          18662929696         destinate group
#
#                                category_f_w
# index_f_w
# 0                  auto restoration service
# 1               shoes other footwear stores
# 2                    real estate developers
# 3          automobile dealers manufacturers
# 4                       business consulting

# %% [markdown]
# Last merge: Facebook-Website dataset and Google dataset

# %%
# create indexer object to identify pairs of rows
indexer = recordlinkage.Index()

# apply blocking on 'domain_f_w' and 'domain_g'
indexer.block(left_on='domain_f_w', right_on='domain_g')

# generate candidate links
candidates = indexer.index(merged_f_w, gd)

print(f"Number of potential matches: {len(candidates)}")
# Out:
# Number of potential matches: 507605

# %%
# create compare object
compare = recordlinkage.Compare()

# compare country exactly
compare.exact('country_f_w', 'country_g', label='country_score', missing_value=1)

# compare city exactly
compare.exact('city_f_w', 'city_g', label='city_score', missing_value=1)

# compare region exactly
compare.exact('region_f_w', 'region_g', label='region_score', missing_value=1)

# compare name using Jaro-Winkler similarity
compare.string('name_f_w',
            'name_g',
            method='jarowinkler',
            threshold=0.85,
            label='name_score',
            missing_value=1)

import time

# record start time
t = time.time()

# compute feature vectors for candidate links
features = compare.compute(candidates, merged_f_w, gd)

# calculate elapsed time
interval = time.time() - t

print(f"Computing time: {interval} seconds")
# Out:
# Computing time: 3.874389171600342 seconds

# %%
features.head()
# Out:
#                    country_score  city_score  region_score  name_score
# index_f_w index_g
# 0         283561               1           1             1           1
# 1         122511               1           0             0           1
# 2         75533                1           0             0           0
#           87518                1           0             0           0
#           184991               1           0             0           0

# %%
print(f"Score | Nr.of matches")

# sum features by score, count unique sums and sort in descending order
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# Score | Nr.of matches
# 4     73891
# 3    168720
# 2     90720
# 1    104165
# 0     70109
# Name: count, dtype: int64

# %%
# filter rows where the sum along the row is greater than or equal to 4
filtered = features[features.sum(axis=1) >= 4] 

filtered.reset_index(inplace=True)

# merge 'filtered' and 'merged_f_w' on 'index_f_w', keeping all rows from both
merged = pd.merge(filtered, merged_f_w, left_on='index_f_w', right_index=True, how='outer')

# merge the resulting DataFrame with 'gd' on 'index_g', keeping all rows from both
merged = pd.merge(merged, gd, left_on='index_g', right_index=True, how='outer')

# merge common columns (_f_w and _g)
merged['city'] = merged['city_f_w'].combine_first(merged['city_g'])
merged['country'] = merged['country_f_w'].combine_first(merged['country_g'])
merged['region'] = merged['region_f_w'].combine_first(merged['region_g'])
merged['domain'] = merged['domain_f_w'].combine_first(merged['domain_g'])

# keep facebook-website 'phone' column (or google if facebook-website is null)
merged['phone'] = merged['phone_f_w'].fillna(merged['phone_g'])

# keep facebook-website 'name' column (or google if facebook-website is null)
merged['name'] = merged['name_f_w'].fillna(merged['name_g'])

# keep facebook-website 'category' column (or google if facebook-website is null)
merged['category'] = merged['category_f_w'].fillna(merged['category_g'])

# drop columns (_f_w and _g)
merged = merged.drop(['index_f_w', 'index_g', 'country_score', 'city_score', 'region_score', 'name_score',
                      'city_f_w', 'country_f_w', 'name_f_w', 'phone_f_w', 'region_f_w', 'category_f_w', 'domain_f_w',
                      'city_g', 'country_g', 'name_g', 'phone_g', 'region_g', 'category_g', 'domain_g' ], axis=1)
merged.head()
# Out:
#     adress_f_w country_code_f_w description_f_w email_f_w link_f_w  \
# NaN        NaN              NaN             NaN       NaN      NaN
# NaN        NaN              NaN             NaN       NaN      NaN
# NaN        NaN              NaN             NaN       NaN      NaN
# NaN        NaN              NaN             NaN       NaN      NaN
# NaN        NaN              NaN             NaN       NaN      NaN
#
#     page_type_f_w phone_country_code_f_w region_code_f_w zip_code_f_w  \
# NaN           NaN                    NaN             NaN          NaN
# NaN           NaN                    NaN             NaN          NaN
# NaN           NaN                    NaN             NaN          NaN
# NaN           NaN                    NaN             NaN          NaN
# NaN           NaN                    NaN             NaN          NaN
#
#     domain_suffix_f_w  ... region_code_g  \
# NaN               NaN  ...           nsw
# NaN               NaN  ...            on
# NaN               NaN  ...            ns
# NaN               NaN  ...            ca
# NaN               NaN  ...          <NA>
#
#                                              details_g zip_code_g  \
# NaN  4.1 (766) · craft store west gosford nsw, aust...       2250
# NaN  4.7 (100) · book store 400 scott st · in grant...    l2m 3w2
# NaN  4.7 (40) · building materials store 7+ years i...    b5a 2j9
# NaN  4.3 (15) · medical spa 7+ years in business · ...      90025
# NaN         5.0 (1) · mobile caterer open ⋅ closes 9pm       <NA>
#
#               city        country           region               domain  \
# NaN        gosford      australia  new south wales  spotlightstores.com
# NaN  st catharines         canada          ontario      bookmanager.com
# NaN       yarmouth         canada      nova scotia        timbermart.ca
# NaN    los angeles  united states       california            linktr.ee
# NaN           <NA>           <NA>             <NA>            linktr.ee
#
#            phone                                name  \
# NaN  61243355946              spotlight west gosford
# NaN  19059374553       heritage christian book store
# NaN  19027429181                pleasant timber mart
# NaN  18184268353  skin specifics medical spa west la
# NaN         <NA>                       lakay express
#
#                               category
# NaN            fabric based home goods
# NaN                        book stores
# NaN  other building material retailers
# NaN            plastic surgery clinics
# NaN                  catering delivery
#
# [5 rows x 28 columns]

# %%
# merge common columns that were not compared but have exact values (_f_w and _g)
merged['zip_code'] = merged['zip_code_f_w'].combine_first(merged['zip_code_g'])
merged['country_code'] = merged['country_code_f_w'].combine_first(merged['country_code_g'])
merged['phone_country_code'] = merged['phone_country_code_f_w'].combine_first(merged['phone_country_code_g'])
merged['region_code'] = merged['region_code_f_w'].combine_first(merged['region_code_g'])

# drop columns (_f_w and _g)
merged = merged.drop(['zip_code_f_w', 'zip_code_g', 'country_code_f_w', 'country_code_g', 'phone_country_code_f_w',
                      'phone_country_code_g', 'region_code_f_w', 'region_code_g', 'adress_f_w'], axis=1)

# rename columns in final dataset
merged = merged.rename(columns={'description_f_w': 'description', 'email_f_w': 'email', 'link_f_w': 'link',
                       'page_type_f_w': 'page_type', 'domain_suffix_f_w': 'domain_suffix', 'language_f_w': 'language',
                       'legal_name_f_w': 'legal_name', 'tld_f_w': 'tld', 'address_g': 'address', 'raw_address_g': 'raw_address',
                       'raw_phone_g': 'raw_phone', 'details_g': 'details'})

# reorder columns in final dataset
merged = merged[['name', 'category', 'country', 'region', 'city', 'phone', 'domain', 'address', 'description',
                 'details', 'email', 'link', 'zip_code', 'country_code', 'region_code', 'phone_country_code','language',
                 'legal_name', 'page_type', 'domain_suffix', 'tld', 'raw_address', 'raw_phone']]

# rename final dataset
final_merge = merged

# reset index
final_merge.reset_index(inplace=True)
final_merge = final_merge.drop(['index'], axis=1)

# count and drop duplicates
original_length = len(final_merge)

final_merge = final_merge.drop_duplicates()
new_length = len(final_merge)
num_duplicates = original_length - new_length
print(f"Number of duplicates dropped in final dataset: {num_duplicates}")
# Out:
# Number of duplicates dropped in final dataset: 220

# %%
# save the final dataset
final_merge.to_csv('final_datasets_join.csv')

final_merge.head(50)
# Out:
#                                                  name  \
# 0                              spotlight west gosford
# 1                       heritage christian book store
# 2                                pleasant timber mart
# 3                  skin specifics medical spa west la
# 4                                       lakay express
# 5               b nektar meadery taproom headquarters
# 6                                               icare
# 7                   south cleveland avenue kindercare
# 8                             torrey pines kindercare
# 9                              meadowlands kindercare
# 10                                  maumee kindercare
# 11                    kindercare at rivier university
# 12                                      brem henry md
# 13          the johns hopkins hospital emergency room
# 14                           ann o shea scheimann m d
# 15                                  jager photography
# 16                                          halo hair
# 17                                      brushworks417
# 18                                          mindscape
# 19                 one more rep gymnasium sri serdang
# 20                                  claws nail studio
# 21                                  cynthia rose arts
# 22                             lowlands project space
# 23                           bright forest art studio
# 24                                      drive concept
# 25                                      sultanfitness
# 26                                     allstar energy
# 27                             daniel thomas weddings
# 28                                     april salonsck
# 29                           premier publishing group
# 30                                           can levi
# 31                                     kedaiqu pevita
# 32                                      sage printing
# 33                                         302 notary
# 34                           vicky finnegan insurance
# 35                              american tax services
# 36                                center city breathe
# 37                                pra health sciences
# 38                                         pop a lock
# 39                           pop a lock simcoe county
# 40  jean coutu claude et nathalie lemonde pharmaciens
# 41                                             okaidi
# 42                             luv em lash extensions
# 43                                       rfg plumbing
# 44                                    broome hospital
# 45                               librairie la liberte
# 46                               librairie la liberte
# 47                 global physiotherapy sherwood park
# 48                    grains research and development
# 49                           making waves swim school
#
#                                          category         country  \
# 0                         fabric based home goods       australia
# 1                                     book stores          canada
# 2               other building material retailers          canada
# 3                         plastic surgery clinics   united states
# 4                               catering delivery            <NA>
# 5                                       pubs bars   united states
# 6                         health insurance agency       australia
# 7                        preschools kindergartens   united states
# 8                        preschools kindergartens   united states
# 9                        preschools kindergartens            <NA>
# 10                       preschools kindergartens   united states
# 11                       preschools kindergartens   united states
# 12                                    pediatrists   united states
# 13                    clinics surgeons physicians   united states
# 14                                    pediatrists   united states
# 15             photographers photographic studios            <NA>
# 16               beauty salons equipment supplies          canada
# 17                  paints coatings dyes pigments   united states
# 18                           spa wellness centers   united states
# 19                                           <NA>        malaysia
# 20                                  beauty salons  united kingdom
# 21                        tattoo piercing parlors         belgium
# 22                                  art galleries          canada
# 23                                  art galleries          canada
# 24                        motorcycle repair shops          france
# 25                    gyms fitness health centers  united kingdom
# 26                  electrical wiring contractors            <NA>
# 27                                           <NA>            <NA>
# 28               beauty salons equipment supplies   united states
# 29                               furniture stores            <NA>
# 30                                           <NA>          turkey
# 31                                    restaurants            <NA>
# 32                            commercial printing            <NA>
# 33                                       notaries            <NA>
# 34              insurance agents carriers brokers            <NA>
# 35  executive legislative government institutions   united states
# 36                                           <NA>   united states
# 37                  industrial machinery supplies   united states
# 38                                     locksmiths         denmark
# 39           alarms surveillance security systems          canada
# 40                                           <NA>          canada
# 41                                           <NA>          france
# 42                        tattoo piercing parlors          canada
# 43                              plumbing services          canada
# 44                    clinics surgeons physicians       australia
# 45                                    book stores          canada
# 46                                    book stores          canada
# 47               sports medicine physical therapy          canada
# 48                                packing crating       australia
# 49                      learning tutoring courses          canada
#
#                           region            city          phone  \
# 0                new south wales         gosford    61243355946
# 1                        ontario   st catharines    19059374553
# 2                    nova scotia        yarmouth    19027429181
# 3                     california     los angeles    18184268353
# 4                           <NA>            <NA>           <NA>
# 5                       michigan        ferndale    13137446323
# 6                new south wales          sydney       61134422
# 7                           ohio     westerville    16148990026
# 8                         nevada       las vegas    17023670822
# 9                           <NA>            <NA>    16514296316
# 10                          ohio          maumee    14198938206
# 11                 new hampshire          nashua    16038880442
# 12                      maryland       baltimore    14109556406
# 13                      maryland       baltimore    14109555000
# 14                      maryland       baltimore    14439975437
# 15                          <NA>            <NA>    16476770357
# 16                       ontario          london           <NA>
# 17                      missouri     springfield    14177559497
# 18                       florida           doral    19203413041
# 19                      selangor  seri kembangan    60389574575
# 20                       england   south wigston           <NA>
# 21                      flanders           tielt           <NA>
# 22                       alberta        edmonton    17808028874
# 23              british columbia      port moody    16047885886
# 24                     occitanie        toulouse    33749663359
# 25                       england         romford   447411370286
# 26                          <NA>            <NA>    19028773629
# 27                          <NA>            <NA>           <NA>
# 28                      new york        new york    12122651700
# 29                          <NA>            <NA>    18002108133
# 30                      istanbul        istanbul   905370266825
# 31                          <NA>            <NA>  6281224145658
# 32                          <NA>            <NA>   447729134033
# 33                          <NA>            <NA>    13024011007
# 34                          <NA>            <NA>   447861536416
# 35                 massachusetts          boston    16175694067
# 36                  pennsylvania    philadelphia           <NA>
# 37                north carolina         raleigh    19197868200
# 38               central jutland             tim    15197807719
# 39                       ontario          barrie    17059845625
# 40                        quebec         beloeil    14504670296
# 41               hauts-de-france         venette    33344432088
# 42                       ontario      belleville    16137433143
# 43                       ontario           essex    15198177117
# 44             western australia          broome    61891942222
# 45                        quebec          quebec    14186583640
# 46                        quebec      sainte foy    14186583640
# 47                       alberta   sherwood park    17804679098
# 48  australian capital territory          barton    61261664500
# 49                       ontario           maple    19058327665
#
#                         domain  \
# 0          spotlightstores.com
# 1              bookmanager.com
# 2                timbermart.ca
# 3                    linktr.ee
# 4                    linktr.ee
# 5                    linktr.ee
# 6             icare.nsw.gov.au
# 7               kindercare.com
# 8               kindercare.com
# 9               kindercare.com
# 10              kindercare.com
# 11              kindercare.com
# 12         hopkinsmedicine.org
# 13         hopkinsmedicine.org
# 14         hopkinsmedicine.org
# 15               instagram.com
# 16               instagram.com
# 17               instagram.com
# 18               instagram.com
# 19               instagram.com
# 20               instagram.com
# 21               instagram.com
# 22               instagram.com
# 23               instagram.com
# 24               instagram.com
# 25               instagram.com
# 26               instagram.com
# 27               instagram.com
# 28               instagram.com
# 29               instagram.com
# 30               instagram.com
# 31               instagram.com
# 32               instagram.com
# 33               instagram.com
# 34               instagram.com
# 35               instagram.com
# 36               instagram.com
# 37                   prahs.com
# 38                 popalock.ca
# 39                 popalock.ca
# 40               jeancoutu.com
# 41                   okaidi.fr
# 42             luvemlashes.com
# 43             rfgplumbing.com
# 44  wacountry.health.wa.gov.au
# 45      librairielaliberte.com
# 46      librairielaliberte.com
# 47     globalphysiotherapy.com
# 48                 grdc.com.au
# 49                     mwss.ca
#
#                                               address  \
# 0   28 central coast hwy west gosford nsw 2250 aus...
# 1        400 scott st st catharines on l2m 3w2 canada
# 2          191 pleasant st yarmouth ns b5a 2j9 canada
# 3   11040 santa monica blvd suite 370 los angeles ...
# 4                                                <NA>
# 5                           ferndale mi united states
# 6               321 kent st sydney nsw 2000 australia
# 7             55 s cleveland ave westerville oh 43081
# 8   4050 s torrey pines dr las vegas nv 89103 unit...
# 9      7 years in business · st paul mn united states
# 10                125 chesterfield ln maumee oh 43537
# 11                      29 clement st nashua nh 03060
# 12            600 n wolfe st 7 113 baltimore md 21287
# 13                 1800 orleans st baltimore md 21287
# 14                  200 n wolfe st baltimore md 21287
# 15                                               <NA>
# 16           363 horton st e london on n6b 1l6 canada
# 17                       springfield mo united states
# 18                                           doral fl
# 19  22a 3 jalan 18 32 taman sri serdang 43300 seri...
# 20  europa house newton ln wigston le18 3se united...
# 21             stedemolenstraat 12 8700 tielt belgium
# 22          11208 65 st nw edmonton ab t5w 4k3 canada
# 23  3082 st johns st 2nd floor port moody bc v3h 2...
# 24           41 rue michel ange 31200 toulouse france
# 25                             romford united kingdom
# 26                             hatchet lake ns canada
# 27                                               <NA>
# 28       587 5th ave 4th fl space 1 new york ny 10017
# 29                                               <NA>
# 30  rasimpasa muhendis sarı ali sk no 15 34716 kad...
# 31                   bandung city west java indonesia
# 32                                               <NA>
# 33                                               <NA>
# 34                                               <NA>
# 35                 93 chelsea st east boston ma 02128
# 36              1425 federal st philadelphia pa 19146
# 37             4130 parklake ave 400 raleigh nc 27612
# 38                                               <NA>
# 39                                               <NA>
# 40          350 rue laurier beloeil qc j3g 4g7 canada
# 41  centre commercial carrefour 6 avenue de l euro...
# 42        146 moira st w belleville on k8p 1t3 canada
# 43                                               <NA>
# 44               robinson st broome wa 6725 australia
# 45                                               <NA>
# 46                                               <NA>
# 47  2693 broadmoor blvd unit 148 sherwood park ab ...
# 48  east building 4 4 national circuit barton act ...
# 49      10557 keele st unit 2 maple on l6a 0j5 canada
#
#                                           description  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6    matt’s story: living with a spinal cord injury 7
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  “the reason that i chose research is because i...
# 38                                                NaN
# 39                                               <NA>
# 40                                                NaN
# 41                                                NaN
# 42                                               <NA>
# 43  frank giles and his sons ryan & brandon starte...
# 44                                                NaN
# 45                                                NaN
# 46  fondée en 1945, la librairie la liberté est an...
# 47                                               <NA>
# 48                                                NaN
# 49                                                NaN
#
#                                               details  ... country_code  \
# 0   4.1 (766) · craft store west gosford nsw, aust...  ...           au
# 1   4.7 (100) · book store 400 scott st · in grant...  ...           ca
# 2   4.7 (40) · building materials store 7+ years i...  ...           ca
# 3   4.3 (15) · medical spa 7+ years in business · ...  ...           us
# 4          5.0 (1) · mobile caterer open ⋅ closes 9pm  ...         <NA>
# 5   4.8 (296) · $$ · bar ferndale, mi, united stat...  ...           us
# 6   2.3 (187) · insurance company sydney nsw, aust...  ...           au
# 7   3.6 (20) · preschool 7+ years in business · we...  ...           us
# 8   3.8 (11) · preschool 7+ years in business · la...  ...           us
# 9   4.8 (9) · kindergarten 1000 meadowlands dr clo...  ...           us
# 10  4.6 (10) · preschool 7+ years in business · ma...  ...           us
# 11  5.0 (1) · day care center nashua, nh closed ⋅ ...  ...           us
# 12  no reviews · neurologist baltimore, md (410) 9...  ...           us
# 13  emergency room baltimore, md · (410) 955-5000 ...  ...         <NA>
# 14  no reviews · pediatrician baltimore, md (443) ...  ...           us
# 15  5.0 (5) · photographer open 24 hours · +1 647-...  ...           ca
# 16  4.7 (3) · hairdresser 363 horton st e closed ⋅...  ...         <NA>
# 17  5.0 (6) · painter springfield, mo, united stat...  ...           us
# 18  no reviews · day spa doral, fl closes soon ⋅ 8...  ...           us
# 19  4.4 (144) · gym & fitness center 3+ years in b...  ...           my
# 20  no reviews · nail salon united kingdom tempora...  ...         <NA>
# 21  no reviews · tattoo shop tielt, belgium tempor...  ...           be
# 22  no reviews · art studio edmonton, ab, canada o...  ...           ca
# 23  no reviews · art studio port moody, bc, canada...  ...           ca
# 24  5.0 (3) · motor scooter dealer toulouse, franc...  ...           fr
# 25  no reviews · personal trainer romford, united ...  ...           gb
# 26  5.0 (1) · electrician hatchet lake, ns, canada...  ...           ca
# 27                                               <NA>  ...         <NA>
# 28  no reviews · hairdresser 587 5th ave 4th fl. s...  ...           us
# 29  no reviews · publisher closed ⋅ opens 9am tue ...  ...         <NA>
# 30  kadıköy/i̇stanbul, turkey open ⋅ closes 8:30pm...  ...           tr
# 31  4.7 (7) · restaurant bandung city, west java, ...  ...           id
# 32  no reviews · print shop closed ⋅ opens 10am fr...  ...           gb
# 33  no reviews · notary public closed ⋅ opens 12am...  ...         <NA>
# 34  5.0 (1) · insurance broker open 24 hours · +44...  ...           gb
# 35  3.9 (11) · tax assessor east boston, ma closed...  ...         <NA>
# 36           5.0 (1) · fitness center 1425 federal st  ...         <NA>
# 37  4.0 (8) · corporate office raleigh, nc closed ...  ...           us
# 38  4.8 (132) · locksmith 7+ years in business clo...  ...           ca
# 39  4.8 (132) · locksmith 7+ years in business clo...  ...           ca
# 40  new on google pharmacy beloeil, quebec, canada...  ...           ca
# 41  4.3 (15) · children's clothing store venette, ...  ...           fr
# 42  5.0 (3) · health and beauty shop 146 moira st ...  ...           ca
# 43  4.8 (308) · plumber 3+ years in business · can...  ...           ca
# 44  general hospital broome wa, australia · +61 8 ...  ...           au
# 45  quebec city, quebec, canada closes soon ⋅ 5:30...  ...           ca
# 46  quebec city, quebec, canada closes soon ⋅ 5:30...  ...           ca
# 47  5.0 (97) · physical therapist sherwood park, a...  ...           ca
# 48  5.0 (2) · research and product development bar...  ...           au
# 49  4.6 (52) · swimming instructor maple, on, cana...  ...           ca
#
#    region_code phone_country_code language legal_name      page_type  \
# 0          nsw                 au      NaN        NaN            NaN
# 1           on                 ca      NaN        NaN            NaN
# 2           ns                 ca      NaN        NaN            NaN
# 3           ca                 us      NaN        NaN            NaN
# 4         <NA>               <NA>      NaN        NaN            NaN
# 5           mi                 us      NaN        NaN            NaN
# 6          nsw               <NA>       en       <NA>   organization
# 7           oh               <NA>      NaN        NaN            NaN
# 8           nv                 us      NaN        NaN            NaN
# 9         <NA>                 us      NaN        NaN            NaN
# 10          oh               <NA>      NaN        NaN            NaN
# 11          nh               <NA>      NaN        NaN            NaN
# 12          md               <NA>      NaN        NaN            NaN
# 13          md               <NA>      NaN        NaN            NaN
# 14          md               <NA>      NaN        NaN            NaN
# 15        <NA>                 ca      NaN        NaN            NaN
# 16          on               <NA>      NaN        NaN            NaN
# 17          mo                 us      NaN        NaN            NaN
# 18          fl               <NA>      NaN        NaN            NaN
# 19          10               <NA>      NaN        NaN            NaN
# 20         eng               <NA>      NaN        NaN            NaN
# 21         vlg               <NA>      NaN        NaN            NaN
# 22          ab                 ca      NaN        NaN            NaN
# 23          bc                 ca      NaN        NaN            NaN
# 24         occ                 fr      NaN        NaN            NaN
# 25         eng                 gb      NaN        NaN            NaN
# 26        <NA>                 ca      NaN        NaN            NaN
# 27        <NA>               <NA>      NaN        NaN            NaN
# 28          ny                 us      NaN        NaN            NaN
# 29        <NA>               <NA>      NaN        NaN            NaN
# 30          34                 tr      NaN        NaN            NaN
# 31        <NA>                 id      NaN        NaN            NaN
# 32        <NA>                 gb      NaN        NaN            NaN
# 33        <NA>               <NA>      NaN        NaN            NaN
# 34        <NA>                 gb      NaN        NaN            NaN
# 35          ma               <NA>      NaN        NaN            NaN
# 36          pa               <NA>      NaN        NaN            NaN
# 37          nc                 us      NaN        NaN  localbusiness
# 38        <NA>                 ca       en       <NA>            NaN
# 39          on                 ca      NaN        NaN  localbusiness
# 40          qc                 ca      NaN        NaN            NaN
# 41         hdf                 fr      NaN        NaN            NaN
# 42          on                 ca       en       <NA>  localbusiness
# 43          on                 ca      NaN        NaN  localbusiness
# 44          wa                 au      NaN        NaN            NaN
# 45        <NA>                 ca       fr       <NA>            NaN
# 46          qc                 ca      NaN        NaN  localbusiness
# 47          ab                 ca      NaN        NaN  localbusiness
# 48         act                 au      NaN        NaN            NaN
# 49          on                 ca      NaN        NaN            NaN
#
#    domain_suffix  tld                                        raw_address  \
# 0            NaN  NaN                        west gosford nsw, australia
# 1            NaN  NaN                   400 scott st · in grantham plaza
# 2            NaN  NaN        7+ years in business · yarmouth, ns, canada
# 3            NaN  NaN  7+ years in business · 11040 santa monica blvd...
# 4            NaN  NaN                                               <NA>
# 5            NaN  NaN                        ferndale, mi, united states
# 6         gov.au   au                              sydney nsw, australia
# 7            NaN  NaN             7+ years in business · westerville, oh
# 8            NaN  NaN  7+ years in business · las vegas, nv, united s...
# 9            NaN  NaN  7+ years in business · st paul, mn, united states
# 10           NaN  NaN                  7+ years in business · maumee, oh
# 11           NaN  NaN                                         nashua, nh
# 12           NaN  NaN                                      baltimore, md
# 13           NaN  NaN                     baltimore, md · (410) 955-5000
# 14           NaN  NaN                                      baltimore, md
# 15           NaN  NaN                                               <NA>
# 16           NaN  NaN                                    363 horton st e
# 17           NaN  NaN                     springfield, mo, united states
# 18           NaN  NaN                                          doral, fl
# 19           NaN  NaN    3+ years in business · seri kembangan, selangor
# 20           NaN  NaN                                               <NA>
# 21           NaN  NaN                                     tielt, belgium
# 22           NaN  NaN                               edmonton, ab, canada
# 23           NaN  NaN                             port moody, bc, canada
# 24           NaN  NaN                                   toulouse, france
# 25           NaN  NaN                            romford, united kingdom
# 26           NaN  NaN                           hatchet lake, ns, canada
# 27           NaN  NaN                                               <NA>
# 28           NaN  NaN                        587 5th ave 4th fl. space 1
# 29           NaN  NaN                                               <NA>
# 30           NaN  NaN                                               <NA>
# 31           NaN  NaN                 bandung city, west java, indonesia
# 32           NaN  NaN                                               <NA>
# 33           NaN  NaN                                               <NA>
# 34           NaN  NaN                                               <NA>
# 35           NaN  NaN                                    east boston, ma
# 36           NaN  NaN                                    1425 federal st
# 37           NaN  NaN                                        raleigh, nc
# 38            ca   ca                                               <NA>
# 39           NaN  NaN                                               <NA>
# 40           NaN  NaN                                               <NA>
# 41           NaN  NaN  venette, france · in centre commercial carrefo...
# 42           com  com                                     146 moira st w
# 43           NaN  NaN                                               <NA>
# 44           NaN  NaN             broome wa, australia · +61 8 9194 2222
# 45           com  com                                               <NA>
# 46           NaN  NaN                                               <NA>
# 47           NaN  NaN     sherwood park, ab, canada · in broadmoor place
# 48           NaN  NaN                              barton act, australia
# 49           NaN  NaN                                  maple, on, canada
#
#             raw_phone
# 0     +61 2 4335 5946
# 1     +1 905-937-4553
# 2     +1 902-742-9181
# 3     +1 818-426-8353
# 4                <NA>
# 5     +1 313-744-6323
# 6                <NA>
# 7      (614) 899-0026
# 8     +1 702-367-0822
# 9      (651) 429-6316
# 10     (419) 893-8206
# 11     (603) 888-0442
# 12     (410) 955-6406
# 13     (410) 955-5000
# 14     (443) 997-5437
# 15    +1 647-677-0357
# 16               <NA>
# 17    +1 417-755-9497
# 18     (920) 341-3041
# 19       03-8957 4575
# 20               <NA>
# 21               <NA>
# 22    +1 780-802-8874
# 23    +1 604-788-5886
# 24  +33 7 49 66 33 59
# 25    +44 7411 370286
# 26    +1 902-877-3629
# 27               <NA>
# 28     (212) 265-1700
# 29     (800) 210-8133
# 30  +90 537 026 68 25
# 31  +62 812-2414-5658
# 32    +44 7729 134033
# 33     (302) 401-1007
# 34    +44 7861 536416
# 35     (617) 569-4067
# 36               <NA>
# 37     (919) 786-8200
# 38    +1 613-241-2323
# 39    +1 613-241-2323
# 40    +1 450-467-0296
# 41  +33 3 44 43 20 88
# 42    +1 613-743-3143
# 43    +1 519-817-7117
# 44    +61 8 9194 2222
# 45    +1 418-658-3640
# 46    +1 418-658-3640
# 47    +1 780-467-9098
# 48    +61 2 6166 4500
# 49    +1 905-832-7665
#
# [50 rows x 23 columns]

# %%
final_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 387282 entries, 0 to 387501
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   name                387243 non-null  object
#  1   category            341918 non-null  object
#  2   country             348854 non-null  object
#  3   region              346634 non-null  object
#  4   city                346811 non-null  object
#  5   phone               351827 non-null  object
#  6   domain              387280 non-null  object
#  7   address             322392 non-null  object
#  8   description         30619 non-null   object
#  9   details             345330 non-null  object
#  10  email               21069 non-null   object
#  11  link                85243 non-null   object
#  12  zip_code            279303 non-null  object
#  13  country_code        314771 non-null  object
#  14  region_code         317354 non-null  object
#  15  phone_country_code  246033 non-null  object
#  16  language            75874 non-null   object
#  17  legal_name          37353 non-null   object
#  18  page_type           85239 non-null   object
#  19  domain_suffix       81516 non-null   object
#  20  tld                 81367 non-null   object
#  21  raw_address         303970 non-null  object
#  22  raw_phone           320789 non-null  object
# dtypes: object(23)
# memory usage: 70.9+ MB
