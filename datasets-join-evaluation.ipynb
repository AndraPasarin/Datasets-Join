# %% [markdown]
# <a href="https://www.kaggle.com/code/andrapsrin/datasets-join-evaluation?scriptVersionId=170946806" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np 
import pandas as pd 

# !pip install recordlinkage
# Out:
# Collecting recordlinkage
#   Downloading recordlinkage-0.16-py3-none-any.whl.metadata (8.1 kB)
# Collecting jellyfish>=1 (from recordlinkage)
#   Downloading jellyfish-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.13 in /opt/conda/lib/python3.10/site-packages (from recordlinkage) (1.26.4)
# Requirement already satisfied: pandas<3,>=1 in /opt/conda/lib/python3.10/site-packages (from recordlinkage) (2.2.1)
# Requirement already satisfied: scipy>=1 in /opt/conda/lib/python3.10/site-packages (from recordlinkage) (1.11.4)
# Requirement already satisfied: scikit-learn>=1 in /opt/conda/lib/python3.10/site-packages (from recordlinkage) (1.2.2)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from recordlinkage) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1->recordlinkage) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1->recordlinkage) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1->recordlinkage) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1->recordlinkage) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1->recordlinkage) (1.16.0)
# Downloading recordlinkage-0.16-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.9/926.9 kB 9.6 MB/s eta 0:00:00
# Downloading jellyfish-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.1 MB/s eta 0:00:00
# Installing collected packages: jellyfish, recordlinkage
# Successfully installed jellyfish-1.0.3 recordlinkage-0.16

# %%
# test entries for facebook_website dataset
test_fd_wd = pd.read_csv('/kaggle/input/accuracy-test/test_fd_wd.csv')
test_fd_wd.head()
# Out:
#       city_f_w     country_f_w              name_f_w   region_f_w  \
# 0  baton rouge   united states                   lsu    louisiana
# 1   letchworth  united kingdom              kwik fit      england
# 2  scarborough          canada      guild inn estate      ontario
# 3        laval          canada  signature boisbriand       quebec
# 4      corinth   united states                  mrhc  mississippi
#
#                    domain_f_w
# 0                     lsu.edu
# 1                kwik-fit.com
# 2          guildinnestate.com
# 3  developpementsignature.com
# 4                    mrhc.org

# %%
# test entries for google dataset
test_gd = pd.read_csv('/kaggle/input/accuracy-test/tets_gd.csv')
test_gd.head()
# Out:
#           city_g      country_g                         name_g  \
# 0        gosford      australia         spotlight west gosford
# 1  st catharines         canada  heritage christian book store
# 2         maumee  united states              maumee kindercare
# 3        houston  united states              energy resourcing
# 4        sanford  united states                scfd station 34
#
#           region_g              domain_g
# 0  new south wales   spotlightstores.com
# 1          ontario       bookmanager.com
# 2             ohio        kindercare.com
# 3            texas  energyresourcing.com
# 4          florida  seminolecountyfl.gov

# %%
# ground truth dataset computed manually from the test data (test_fd_wd + test_gd) by the expert (me)
true_pred = pd.read_csv('/kaggle/input/accuracy-test/true_pred.csv')
true_pred.head()
# Out:
#             city        country                           name  \
# 0        gosford      australia         spotlight west gosford
# 1  st catharines         canada  heritage christian book store
# 2         maumee  united states              maumee kindercare
# 3        houston  united states              energy resourcing
# 4        sanford  united states                scfd station 34
#
#             region                domain
# 0  new south wales   spotlightstores.com
# 1          ontario       bookmanager.com
# 2             ohio        kindercare.com
# 3            texas  energyresourcing.com
# 4          florida  seminolecountyfl.gov

# %%
# index setup for merging

import recordlinkage

# add index column for each dataset
test_fd_wd = test_fd_wd.reset_index().rename(columns={'index': 'index_f_w'})
test_gd = test_gd.reset_index().rename(columns={'index': 'index_g'})

# set index column for each dataset
test_fd_wd.set_index('index_f_w', inplace=True)
test_gd.set_index('index_g', inplace=True)

# create indexer object to identify pairs of rows
indexer = recordlinkage.Index()

# apply blocking on 'domain_f_w' and 'domain_g'
indexer.block(left_on='domain_f_w', right_on='domain_g')

# generate candidate links
candidates = indexer.index(test_fd_wd, test_gd)

print(f"Number of potential matches: {len(candidates)}")
# Out:
# Number of potential matches: 14

# %%
compare = recordlinkage.Compare()

compare.exact('country_f_w', 'country_g', label='country_score', missing_value=1)
compare.exact('city_f_w', 'city_g', label='city_score', missing_value=1)
compare.exact('region_f_w', 'region_g', label='region_score', missing_value=1)

compare.string('name_f_w',
            'name_g',
            method='jarowinkler',
            threshold=0.85,
            label='name_score',
            missing_value=1)

features = compare.compute(candidates, test_fd_wd, test_gd)

features.head()
# Out:
#                    country_score  city_score  region_score  name_score
# index_f_w index_g
# 0         6                    1           1             1         0.0
# 1         5                    1           0             1         1.0
# 2         7                    1           1             1         0.0
# 3         9                    1           0             1         1.0
# 4         10                   1           1             1         0.0

# %%
# filter and merge
def count_drop_duplicates(dataFrame):
    # print duplicates before dropping
    duplicates = dataFrame[dataFrame.duplicated()]
    if duplicates.empty:
        print("No duplicates found in final dataset.")
        return
    
    print("Duplicates in final dataset:")
    print(duplicates)

    dataFrame = dataFrame.drop_duplicates()
    
    print(f"\nNumber of duplicates dropped in final dataset: {len(duplicates)}")

filtered = features[features.sum(axis=1) >= 4]
filtered.reset_index(inplace=True) 

merged = pd.merge(filtered, test_fd_wd, left_on='index_f_w', right_index=True, how='outer')
merged = pd.merge(merged, test_gd, left_on='index_g', right_index=True, how='outer')    

count_drop_duplicates(merged)
# Out:
# No duplicates found in final dataset.

# %%
# drop index and score columns
merged = merged.drop(['index_f_w', 'index_g', 'country_score', 'region_score', 'name_score', 'city_score'], axis=1)

# merge common columns (_f_w and _g)
merged['city'] = merged['city_f_w'].combine_first(merged['city_g'])
merged['country'] = merged['country_f_w'].combine_first(merged['country_g'])
merged['region'] = merged['region_f_w'].combine_first(merged['region_g'])
merged['domain'] = merged['domain_f_w'].combine_first(merged['domain_g'])

# keep f_w 'phone' column (or google if f_w is null)
merged['name'] = merged['name_f_w'].fillna(merged['name_g'])

# drop columns (_f_w and _g)
merged = merged.drop(['city_f_w', 'country_f_w', 'name_f_w', 'region_f_w', 'domain_f_w',
                      'city_g', 'country_g', 'name_g', 'region_g', 'domain_g'], axis=1)

# reset index
merged.reset_index(inplace=True)
merged = merged.drop(['index'], axis=1)

merged.head(50)
# Out:
#                   city         country            region  \
# 0              gosford       australia   new south wales
# 1        st catharines          canada           ontario
# 2               maumee   united states              ohio
# 3              houston   united states             texas
# 4              sanford   united states           florida
# 5             bradford  united kingdom           england
# 6          baton rouge   united states         louisiana
# 7          scarborough          canada           ontario
# 8            stratford          canada           ontario
# 9           boisbriand          canada            quebec
# 10             corinth   united states       mississippi
# 11              durham   united states    north carolina
# 12             waipahu   united states            hawaii
# 13          plainville   united states     massachusetts
# 14          springwood       australia   new south wales
# 15         mississauga          canada           ontario
# 16          burlington          canada           ontario
# 17  portage la prairie          canada          manitoba
# 18           vancouver          canada  british columbia
# 19             houston   united states             texas
# 20              napier    south africa      western cape
# 21         denver city   united states             texas
# 22             concord   united states    north carolina
# 23          villa park   united states        california
# 24            medellin        colombia         antioquia
# 25        stephenville   united states             texas
# 26           west ryde       australia   new south wales
# 27        christchurch     new zealand        canterbury
# 28             markham          canada           ontario
# 29             chicago   united states          illinois
# 30      thetford mines          canada            quebec
# 31           vancouver          canada  british columbia
# 32              shatin       hong kong           sha tin
# 33             colombo       sri lanka  western province
# 34         baton rouge   united states         louisiana
# 35          letchworth  united kingdom           england
# 36         scarborough          canada           ontario
# 37               laval          canada            quebec
# 38             corinth   united states       mississippi
# 39              durham   united states    north carolina
# 40  south melbourne dc       australia          victoria
# 41             toronto          canada           ontario
# 42          woodbridge          canada           ontario
# 43      woodland hills   united states        california
# 44         mississauga          canada           ontario
# 45           vancouver          canada  british columbia
#
#                            domain  \
# 0             spotlightstores.com
# 1                 bookmanager.com
# 2                  kindercare.com
# 3            energyresourcing.com
# 4            seminolecountyfl.gov
# 5                    kwik-fit.com
# 6                         lsu.edu
# 7              guildinnestate.com
# 8                       jarfh.com
# 9      developpementsignature.com
# 10                       mrhc.org
# 11                      dpsnc.net
# 12                      kumon.com
# 13               plainville.ma.us
# 14          opalhealthcare.com.au
# 15         innovativedisplays.com
# 16                 donnellins.com
# 17                 willowsbend.ca
# 18  collectorscustomfurniture.com
# 19           energyresourcing.com
# 20                    spark.co.nz
# 21                bestwestern.com
# 22                      ncdot.gov
# 23                  orangeusd.org
# 24                        sap.com
# 25           texasagriculture.gov
# 26                certisgroup.com
# 27                 cdhb.health.nz
# 28                babudelivery.ca
# 29                   saintita.org
# 30                       anugo.ca
# 31             vhebrewacademy.com
# 32                   hkedcity.net
# 33                   amanabank.lk
# 34                        lsu.edu
# 35                   kwik-fit.com
# 36             guildinnestate.com
# 37     developpementsignature.com
# 38                       mrhc.org
# 39                      dpsnc.net
# 40            spotlightstores.com
# 41                bookmanager.com
# 42                      kumon.com
# 43                 soundcloud.com
# 44         animalkingdomresort.ca
# 45             vhebrewacademy.com
#
#                                               name
# 0                           spotlight west gosford
# 1                    heritage christian book store
# 2                                maumee kindercare
# 3                                energy resourcing
# 4                                  scfd station 34
# 5                      kwik fit bradford thornbury
# 6                       louisiana state university
# 7                             the guild inn estate
# 8                  james a rutherford funeral home
# 9                             signature boisbriand
# 10  magnolia regional health center emergency room
# 11                club boulevard elementary school
# 12        kumon math and reading center of waipahu
# 13                   plainville highway department
# 14               springwood terrace care community
# 15   innovative displays printing signage displays
# 16                               donnell insurance
# 17                                    willows bend
# 18                     collectors custom furniture
# 19                               energy resourcing
# 20                              spark store napier
# 21      best western plus denver city hotel suites
# 22                  cabarrus county license office
# 23                       serrano elementary school
# 24                                sap colombia sas
# 25                    texas department agriculture
# 26                       certis security australia
# 27                  the princess margaret hospital
# 28                                   babu catering
# 29                       saint ita catholic church
# 30                                 richard service
# 31                        vancouver hebrew academy
# 32                        hong kong education city
# 33                                  amana bank atm
# 34                                             lsu
# 35                                        kwik fit
# 36                                guild inn estate
# 37                            signature boisbriand
# 38                                            mrhc
# 39                           durham public schools
# 40                             spotlight australia
# 41                                     queen books
# 42                                           kumon
# 43                                      soundcloud
# 44                           animal kingdom resort
# 45                                             vha

# %%
# reorder columns
true_pred = true_pred[['city', 'country', 'region', 'domain', 'name']]
true_pred.head(50)
# Out:
#                   city         country            region  \
# 0              gosford       australia   new south wales
# 1        st catharines          canada           ontario
# 2               maumee   united states              ohio
# 3              houston   united states             texas
# 4              sanford   united states           florida
# 5             bradford  united kingdom           england
# 6          baton rouge   united states         louisiana
# 7            stratford          canada           ontario
# 8           boisbriand          canada            quebec
# 9              corinth   united states       mississippi
# 10              durham   united states    north carolina
# 11             waipahu   united states            hawaii
# 12          plainville   united states     massachusetts
# 13          springwood       australia   new south wales
# 14              napier    south africa      western cape
# 15         denver city   united states             texas
# 16             concord   united states    north carolina
# 17          villa park   united states        california
# 18            medellin        colombia         antioquia
# 19        stephenville   united states             texas
# 20           west ryde       australia   new south wales
# 21        christchurch     new zealand        canterbury
# 22             markham          canada           ontario
# 23             chicago   united states          illinois
# 24      thetford mines          canada            quebec
# 25           vancouver          canada  british columbia
# 26              shatin       hong kong           sha tin
# 27             colombo       sri lanka  western province
# 28          letchworth  united kingdom           england
# 29         scarborough          canada           ontario
# 30               laval          canada            quebec
# 31              durham   united states    north carolina
# 32  south melbourne dc       australia          victoria
# 33             toronto          canada           ontario
# 34          woodbridge          canada           ontario
# 35      woodland hills   united states        california
# 36         mississauga          canada           ontario
# 37          burlington          canada           ontario
# 38  portage la prairie          canada          manitoba
# 39           vancouver          canada  british columbia
# 40         mississauga          canada           ontario
#
#                            domain  \
# 0             spotlightstores.com
# 1                 bookmanager.com
# 2                  kindercare.com
# 3            energyresourcing.com
# 4            seminolecountyfl.gov
# 5                    kwik-fit.com
# 6                         lsu.edu
# 7                       jarfh.com
# 8      developpementsignature.com
# 9                        mrhc.org
# 10                      dpsnc.net
# 11                      kumon.com
# 12               plainville.ma.us
# 13          opalhealthcare.com.au
# 14                    spark.co.nz
# 15                bestwestern.com
# 16                      ncdot.gov
# 17                  orangeusd.org
# 18                        sap.com
# 19           texasagriculture.gov
# 20                certisgroup.com
# 21                 cdhb.health.nz
# 22                babudelivery.ca
# 23                   saintita.org
# 24                       anugo.ca
# 25             vhebrewacademy.com
# 26                   hkedcity.net
# 27                   amanabank.lk
# 28                   kwik-fit.com
# 29             guildinnestate.com
# 30     developpementsignature.com
# 31                      dpsnc.net
# 32            spotlightstores.com
# 33                bookmanager.com
# 34                      kumon.com
# 35                 soundcloud.com
# 36         innovativedisplays.com
# 37                 donnellins.com
# 38                 willowsbend.ca
# 39  collectorscustomfurniture.com
# 40         animalkingdomresort.ca
#
#                                               name
# 0                           spotlight west gosford
# 1                    heritage christian book store
# 2                                maumee kindercare
# 3                                energy resourcing
# 4                                  scfd station 34
# 5                      kwik fit bradford thornbury
# 6                       louisiana state university
# 7                  james a rutherford funeral home
# 8                             signature boisbriand
# 9   magnolia regional health center emergency room
# 10                club boulevard elementary school
# 11        kumon math and reading center of waipahu
# 12                   plainville highway department
# 13               springwood terrace care community
# 14                              spark store napier
# 15      best western plus denver city hotel suites
# 16                  cabarrus county license office
# 17                       serrano elementary school
# 18                                sap colombia sas
# 19                    texas department agriculture
# 20                       certis security australia
# 21                  the princess margaret hospital
# 22                                   babu catering
# 23                       saint ita catholic church
# 24                                 richard service
# 25                        vancouver hebrew academy
# 26                        hong kong education city
# 27                                  amana bank atm
# 28                                        kwik fit
# 29                                guild inn estate
# 30                            signature boisbriand
# 31                           durham public schools
# 32                             spotlight australia
# 33                                     queen books
# 34                                           kumon
# 35                                      soundcloud
# 36   innovative displays printing signage displays
# 37                               donnell insurance
# 38                                    willows bend
# 39                     collectors custom furniture
# 40                           animal kingdom resort

# %%
# Evaluation of joining algorithm

ground_truth_joined_dataset = true_pred
join_algorithm_final_dataset = merged


# convert each dataFrame into a set of tuples (the rows are tuples now)
ground_truth_set = set([tuple(x) for x in ground_truth_joined_dataset.to_numpy()])
algorithm_output_set = set([tuple(x) for x in join_algorithm_final_dataset.to_numpy()])

# compute true positives (tp), false positives (fp), and false negatives (fn)
tp = len(ground_truth_set & algorithm_output_set)
fp = len(algorithm_output_set - ground_truth_set)
fn = len(ground_truth_set - algorithm_output_set)

print("True positive count: ", tp)
print("False positive count: ", fp)
print("False negative count: ", fn)

# compute precision, recall and F1 score
precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0
f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print(f"\nPrecision Score: {int(precision * 100)}%")
print(f"Recall Score: {int(recall * 100)}%")
print(f"F1 Score: {int(f1 * 100)}%")
# Out:
# True positive count:  41
# False positive count:  4
# False negative count:  0
#
# Precision Score: 91%
# Recall Score: 100%
# F1 Score: 95%
